# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf-isoscapes/blob/xgbminimal/xgboost/minimal_xgb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Welcome to the XGBoost-based generation of Oxygen Isoscape.
import sys

# !if [ ! -d "/content/ddf_common_stub" ] ; then git clone -b test https://github.com/tnc-br/ddf_common_stub.git; fi
sys.path.append("/content/ddf_common_stub/")

import ddfimport
ddfimport.ddf_source_control_pane()
# Out:
# interactive(children=(Text(value='', description='Email', placeholder='Enter email'), Text(value='', descripti…
