# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf-isoscapes/blob/new_kl/dnn/kriging_variational_ensemble_numerical_individual_transformers_no_val.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kriging + numerical stability + bayesian + ablation
#
#  Train a variational inference model with kriging columns as features, numerical stability, and ablating other models

# %%
from collections import defaultdict
import math
import numpy as np
import pandas as pd
import datetime
import os
from typing import List, Tuple, Dict
from dataclasses import dataclass
from joblib import dump

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from matplotlib import pyplot as plt
from tensorflow.python.ops import math_ops
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler
from sklearn.compose import ColumnTransformer

#@title Debugging
# See https://zohaib.me/debugging-in-google-collab-notebook/ for tips,
# as well as docs for pdb and ipdb.
DEBUG = False #@param {type:"boolean"}
USE_LOCAL_DRIVE = True #@param {type:"boolean"}
LOCAL_DIR = "/usr/local/google/home/ruru/Downloads/amazon_sample_data-20230712T203059Z-001" #@param
GDRIVE_DIR = "MyDrive/amazon_rainforest_files/" #@param
FP_ROOT = LOCAL_DIR

RASTER_BASE = "/MyDrive/amazon_rainforest_files/amazon_rasters/" #@param
MODEL_SAVE_LOCATION = "/usr/local/google/home/ruru/Downloads/model_builds" #@param
OUTPUT_RASTER_BASE = "/MyDrive/amazon_rainforest_files/variational/rasters/" #@param

def get_model_save_location(filename) -> str:
  root = '' if USE_LOCAL_DRIVE else '/content/drive'
  return os.path.join(root, MODEL_SAVE_LOCATION, filename)

# Access data stored on Google Drive if not reading data locally.
if not USE_LOCAL_DRIVE:
  from google.colab import drive
  drive.mount('/content/drive')
  global FP_ROOT
  FP_ROOT = os.path.join('/content/drive', GDRIVE_DIR)

if DEBUG:
    # %pip install -Uqq ipdb
    import ipdb
    # %pdb on
# Out:
# 2023-08-03 16:41:22.446632: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 16:41:22.481341: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 16:41:22.482135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 16:41:23.192571: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data preparation

# %%
def load_dataset(path: str, columns_to_keep: List[str]):
  df = pd.read_csv(path, encoding="ISO-8859-1", sep=',')
  df = df[df['d18O_cel_variance'].notna()]

  X = df.drop(df.columns.difference(columns_to_keep), axis=1)
  Y = df[["d18O_cel_mean", "d18O_cel_variance"]]
  return X, Y

# %% [markdown]
# Standardization

# %%
@dataclass
class FeaturesToLabels:
  def __init__(self, X: pd.DataFrame, Y: pd.DataFrame):
    self.X = X
    self.Y = Y

  def as_tuple(self):
    return (self.X, self.Y)


def create_feature_scaler(X: pd.DataFrame, columns_to_normalize, columns_to_standardize) -> ColumnTransformer:
  feature_scaler = ColumnTransformer(
      [(column+'_normalizer', Normalizer(), [column]) for column in columns_to_normalize] +
      [(column+'_standardizer', StandardScaler(), [column]) for column in columns_to_standardize],
      remainder='passthrough')
  feature_scaler.fit(X)
  return feature_scaler

def create_label_scaler(Y: pd.DataFrame) -> ColumnTransformer:
  label_scaler = ColumnTransformer([
      ('mean_std_scaler', StandardScaler(), ['d18O_cel_mean']),
      ('var_minmax_scaler', MinMaxScaler(), ['d18O_cel_variance'])],
      remainder='passthrough')
  label_scaler.fit(Y)
  return label_scaler

def scale(X: pd.DataFrame, Y: pd.DataFrame, feature_scaler, label_scaler):
  # transform() outputs numpy arrays :(  need to convert back to DataFrame.
  X_standardized = pd.DataFrame(feature_scaler.transform(X),
                        index=X.index, columns=X.columns)
  return FeaturesToLabels(X_standardized, Y)

# %%
# Just a class organization, holds each scaled dataset and the scaler used.
# Useful for unscaling predictions.
@dataclass
class ScaledPartitions():
  def __init__(self,
               feature_scaler: ColumnTransformer,
               label_scaler: ColumnTransformer,
               train: FeaturesToLabels, val: FeaturesToLabels,
               test: FeaturesToLabels):
    self.feature_scaler = feature_scaler
    self.label_scaler = label_scaler
    self.train = train
    self.val = val
    self.test = test


def load_and_scale(config: Dict,
                   columns_to_normalize: List[str],
                   columns_to_standardize: List[str]) -> ScaledPartitions:
  columns_to_keep = columns_to_normalize + columns_to_standardize
  X_train, Y_train = load_dataset(config['TRAIN'], columns_to_keep)
  X_val, Y_val = load_dataset(config['VALIDATION'], columns_to_keep)

  X_train = pd.concat([X_train, X_val])
  Y_train = pd.concat([Y_train, Y_val])

  X_test, Y_test = load_dataset(config['TEST'], columns_to_keep)

  feature_scaler = create_feature_scaler(X_train, columns_to_normalize, columns_to_standardize)
  label_scaler = create_label_scaler(Y_train)
  train = scale(X_train, Y_train, feature_scaler, label_scaler)
  test = scale(X_test, Y_test, feature_scaler, label_scaler)
  return ScaledPartitions(feature_scaler, label_scaler, train, None, test)

# %% [markdown]
# # Model Definition

# %% [markdown]
# The KL Loss function:

# %%
def sample_normal_distribution(
    mean: tf.Tensor,
    stdev: tf.Tensor,
    n: int) -> tf.Tensor:
    '''
    Given a batch of normal distributions described by a mean and stdev in
    a tf.Tensor, sample n elements from each distribution and return the mean
    and standard deviation per sample.
    '''
    batch_size = tf.shape(mean)[0]

    # Output tensor is (n, batch_size, 1)
    sample_values = tfp.distributions.Normal(
        loc=mean,
        scale=stdev).sample(
            sample_shape=n)
    # Reshaped tensor will be (batch_size, n)
    sample_values = tf.transpose(sample_values)
    # Get the mean per sample in the batch.
    sample_mean = tf.transpose(tf.math.reduce_mean(sample_values, 2))
    sample_stdev = tf.transpose(tf.math.reduce_std(sample_values, 2))

    return sample_mean, sample_stdev

import tensorflow_probability as tfp

# log(σ2/σ1) + ( σ1^2+(μ1−μ2)^2 ) / 2* σ^2   − 1/2
def kl_divergence_helper(real, predicted, sample):
    '''
    real: tf.Tensor of the real mean and standard deviation of sample to compare
    predicted: tf.Tensor of the predicted mean and standard deviation to compare
    sample: Whether or not to sample the predicted distribution to get a new
            mean and standard deviation.
    '''
    if real.shape != predicted.shape:
      raise ValueError(
          f"real.shape {real.shape} != predicted.shape {predicted.shape}")

    real_value = tf.gather(real, [0], axis=1)
    real_std = tf.math.sqrt(tf.gather(real, [1], axis=1))


    predicted_value = tf.gather(predicted, [0], axis=1)
    predicted_std = tf.math.sqrt(tf.gather(predicted, [1], axis=1))
    # If true, sample from the distribution defined by the predicted mean and
    # standard deviation to use for mean and stdev used in KL divergence loss.
    if sample:
      predicted_value, predicted_std = sample_normal_distribution(
          mean=predicted_value, stdev=predicted_std, n=10)

    kl_loss = -0.5 + tf.math.log(predicted_std/real_std) + \
     (tf.square(real_std) + tf.square(real_value - predicted_value))/ \
     (2*tf.square(predicted_std))

    return tf.math.reduce_mean(kl_loss)

def kl_divergence(real, predicted):
  return kl_divergence_helper(real, predicted, True)

# %% [markdown]
# Test the loss function:

# %%
import pytest

class TensorsDifferShapeTest(unittest.TestCase):
   def test(self):
      test_real = tf.convert_to_tensor(np.array([[1, 0.02]]))
      test_pred = tf.convert_to_tensor(np.array([[0.98]]))
      with self.assertRaises(ValueError):
         kl_divergence(test_real, test_pred, False)
         assert(False) # Triggers if no exception is caught in the previous line.

TensorsDifferShapeTest().test()

test_real = tf.convert_to_tensor(np.array([[1, 0.02]]))
test_pred = tf.convert_to_tensor(np.array([[0.98, 0.021]]))

# https://screenshot.googleplex.com/5WM9dinAbhR26ZS
assert float(kl_divergence(test_real, test_pred)) == pytest.approx(0.0101094, 1e-5)

test_neg_real = tf.convert_to_tensor(np.array([[32.32, 0.0344]]))
test_neg_pred = tf.convert_to_tensor(np.array([[32.01, -0.322]]))

# Negative variance causes NaN
assert tf.math.is_nan(kl_divergence(test_neg_real, test_neg_pred))

# Calculated manually by computing the result of this equation in wolfram alpha:
# log(σ2/σ1) + ( σ1^2+(μ1−μ2)^2 ) / 2* σ^2   − 1/2
test_real_2d = tf.convert_to_tensor(np.array(
    [[1.00, 0.020],
     [1.01, 0.042]]))
test_pred_2d = tf.convert_to_tensor(np.array(
    [[0.98, 0.021],
     [0.99, 0.012]]))

# Should reduce to the average loss of all rows.
assert float(kl_divergence(test_real_2d, test_pred_2d)) == pytest.approx(
    sum([0.0101094, 0.6402851])/2, 1e-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pytest
# ----> 3 class TensorsDifferShapeTest(unittest.TestCase):
#       4    def test(self):
#       5       test_real = tf.convert_to_tensor(np.array([[1, 0.02]]))
#
# NameError: name 'unittest' is not defined

# %% [markdown]
# Model definition

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

def get_early_stopping_callback():
  return EarlyStopping(monitor='loss', patience=1000, min_delta=0.001,
                       verbose=1, restore_best_weights=True, start_from_epoch=0)

tf.keras.utils.set_random_seed(18731)

# I was experimenting with models that took longer to train, and used this
# checkpointing callback to periodically save the model. It's optional.
def get_checkpoint_callback(model_file):
  return ModelCheckpoint(
      get_model_save_location(model_file),
      monitor='loss', verbose=0, save_best_only=True, mode='min')

def train_or_update_variational_model(
        sp: ScaledPartitions,
        hidden_layers: List[int],
        epochs: int,
        batch_size: int,
        lr: float,
        model_file=None,
        use_checkpoint=False):
  callbacks_list = [get_early_stopping_callback(),
                    get_checkpoint_callback(model_file)]
  if not use_checkpoint:
    inputs = keras.Input(shape=(sp.train.X.shape[1],))
    x = inputs
    for layer_size in hidden_layers:
      x = keras.layers.Dense(
          layer_size, activation='relu')(x)
    mean_output = keras.layers.Dense(
        1, name='mean_output')(x)

    # We can not have negative variance. Apply very little variance.
    var_output = keras.layers.Dense(
        1, name='var_output')(x)

    # Invert the normalization on our outputs
    mean_scaler = sp.label_scaler.named_transformers_['mean_std_scaler']
    untransformed_mean = mean_output * mean_scaler.var_ + mean_scaler.mean_

    var_scaler = sp.label_scaler.named_transformers_['var_minmax_scaler']
    unscaled_var = var_output * var_scaler.scale_ + var_scaler.min_
    untransformed_var = keras.layers.Lambda(lambda t: tf.math.log(1 + tf.exp(t)))(unscaled_var)

    # Output mean,  tuples.
    outputs = keras.layers.concatenate([untransformed_mean, untransformed_var])
    model = keras.Model(inputs=inputs, outputs=outputs)

    optimizer = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=optimizer, loss=kl_divergence)
    model.summary()
  else:
    model = keras.models.load_model(
        get_model_save_location(model_file),
        custom_objects={"kl_divergence": kl_divergence})
  history = model.fit(sp.train.X, sp.train.Y, verbose=1, epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)
  return history, model

# %%
from sklearn.metrics import mean_squared_error

def render_plot_loss(history, name):
  plt.plot(history.history['loss'])
  plt.title(name + ' model loss')
  plt.ylabel('loss')
  plt.yscale("log")
  plt.ylim((0, 10))
  plt.xlabel('epoch')
  plt.legend(['loss'], loc='upper left')
  plt.show()

def train_and_evaluate(sp: ScaledPartitions, run_id: str, training_batch_size=5):
  print("==================")
  print(run_id)
  history, model = train_or_update_variational_model(
      sp, hidden_layers=[20, 20], epochs=5000, batch_size=training_batch_size,
      lr=0.00002, model_file=run_id+".h5", use_checkpoint=False)
  render_plot_loss(history, run_id+" kl_loss")
  model.save(get_model_save_location(run_id+".h5"), save_format="h5")

  best_epoch_index = history.history['loss'].index(min(history.history['loss']))
  print('Train loss:', history.history['loss'][best_epoch_index])
  print('Test loss:', model.evaluate(x=sp.test.X, y=sp.test.Y, verbose=0))

  predictions = model.predict_on_batch(sp.test.X)
  predictions = pd.DataFrame(predictions, columns=['d18O_cel_mean', 'd18O_cel_variance'])
  rmse = np.sqrt(mean_squared_error(sp.test.Y['d18O_cel_mean'], predictions['d18O_cel_mean']))
  print("dO18 RMSE: "+ str(rmse))
  print("EXPECTED:")
  print(sp.test.Y.to_string())
  print()
  print("PREDICTED:")
  print(predictions.to_string())
  return model

# %% [markdown]
# ## 1) Grouped, random
#
# We can't (easily) generate isoscapes with these because the isoscapes for 'predkrig_br_lat_ISORG', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION' are not easily retrievable... but I'm curious how much better the model is if these columns are included.

# %%
grouped_random_fileset = {
    'TRAIN' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_train_random_grouped.csv'),
    'TEST' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_test_random_grouped.csv'),
    'VALIDATION' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_validation_random_grouped.csv'),
}

columns_to_normalize = []
columns_to_standardize = [
                   'lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA',
                   'Mean Annual Temperature','Mean Annual Precipitation',
                   'Iso_Oxi_Stack_mean_TERZER',
                   'isoscape_fullmodel_d18O_prec_REGRESSION',
                   'ordinary_kriging_linear_d18O_predicted_variance',
                   'ordinary_kriging_linear_d18O_predicted_mean']

data = load_and_scale(grouped_random_fileset, columns_to_normalize, columns_to_standardize)
model = train_and_evaluate(data, "kriging_all_random", training_batch_size=3)
model.save(get_model_save_location("kriging_all_random.tf"), save_format='tf')
dump(data.feature_scaler, get_model_save_location('kriging_all_random_transformer.pkl'))

# %% [markdown]
# ### 2) Grouped, random, ablating other models except kriging
#
# We can generate isoscapes for this model easily.

# %%
grouped_random_fileset = {
    'TRAIN' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_train_random_grouped.csv'),
    'TEST' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_test_random_grouped.csv'),
    'VALIDATION' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_validation_random_grouped.csv'),
}


columns_to_normalize = []
columns_to_standardize = ['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA',
                   'Mean Annual Temperature','Mean Annual Precipitation',
                   'ordinary_kriging_linear_d18O_predicted_variance',
                   'ordinary_kriging_linear_d18O_predicted_mean']

data = load_and_scale(grouped_random_fileset, columns_to_normalize, columns_to_standardize)
model = train_and_evaluate(data, "grouped_random_ablated_no_val", training_batch_size=3)
model.save(get_model_save_location("kriging_ablated_random_no_val.tf"), save_format='tf')
dump(data.feature_scaler, get_model_save_location('kriging_ablated_random_no_val_transformer.pkl'))
# Out:
# ==================
# grouped_random_ablated_no_val
# Epoch 1/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.9448
# Epoch 2/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9891
# Epoch 3/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.9202
# Epoch 4/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0131
# Epoch 5/100
# 37/37 [==============================] - 0s 979us/step - loss: 1.0912
# Epoch 6/100
# 37/37 [==============================] - 0s 956us/step - loss: 1.0982
# Epoch 7/100
# 37/37 [==============================] - 0s 972us/step - loss: 1.0032
# Epoch 8/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9086
# Epoch 9/100
# 37/37 [==============================] - 0s 944us/step - loss: 1.3202
# Epoch 10/100
# 37/37 [==============================] - 0s 993us/step - loss: 1.4928
# Epoch 11/100
# 37/37 [==============================] - 0s 978us/step - loss: 1.2764
# Epoch 12/100
# 37/37 [==============================] - 0s 948us/step - loss: 1.1096
# Epoch 13/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1802
# Epoch 14/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0700
# Epoch 15/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.3808
# Epoch 16/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1701
# Epoch 17/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1107
# Epoch 18/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.3027
# Epoch 19/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1632
# Epoch 20/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.2015
# Epoch 21/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0234
# Epoch 22/100
# 37/37 [==============================] - 0s 986us/step - loss: 1.1753
# Epoch 23/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.2367
# Epoch 24/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1835
# Epoch 25/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0788
# Epoch 26/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9404
# Epoch 27/100
# 37/37 [==============================] - 0s 933us/step - loss: 1.0652
# Epoch 28/100
# 37/37 [==============================] - 0s 974us/step - loss: 1.1400
# Epoch 29/100
# 37/37 [==============================] - 0s 994us/step - loss: 1.0819
# Epoch 30/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9971
# Epoch 31/100
# 37/37 [==============================] - 0s 963us/step - loss: 1.2856
# Epoch 32/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9018
# Epoch 33/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0333
# Epoch 34/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9595
# Epoch 35/100
# 37/37 [==============================] - 0s 993us/step - loss: 0.9867
# Epoch 36/100
# 37/37 [==============================] - 0s 963us/step - loss: 1.0274
# Epoch 37/100
# 37/37 [==============================] - 0s 899us/step - loss: 0.9350
# Epoch 38/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9578
# Epoch 39/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.9321
# Epoch 40/100
# 37/37 [==============================] - 0s 945us/step - loss: 1.4122
# Epoch 41/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1192
# Epoch 42/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.0226
# Epoch 43/100
# 37/37 [==============================] - 0s 990us/step - loss: 1.0704
# Epoch 44/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.1649
# Epoch 45/100
# 37/37 [==============================] - 0s 943us/step - loss: 1.0862
# Epoch 46/100
# 37/37 [==============================] - 0s 950us/step - loss: 1.0576
# Epoch 47/100
# 37/37 [==============================] - 0s 966us/step - loss: 1.1616
# Epoch 48/100
# 37/37 [==============================] - 0s 988us/step - loss: 0.9210
# Epoch 49/100
# 37/37 [==============================] - 0s 872us/step - loss: 1.0703
# Epoch 50/100
# 37/37 [==============================] - 0s 919us/step - loss: 1.2188
# Epoch 51/100
# 37/37 [==============================] - 0s 947us/step - loss: 1.0937
# Epoch 52/100
# 37/37 [==============================] - 0s 886us/step - loss: 1.0949
# Epoch 53/100
# 37/37 [==============================] - 0s 909us/step - loss: 1.0560
# Epoch 54/100
# 37/37 [==============================] - 0s 970us/step - loss: 1.2302
# Epoch 55/100
# 37/37 [==============================] - 0s 967us/step - loss: 1.3313
# Epoch 56/100
# 37/37 [==============================] - 0s 927us/step - loss: 1.0498
# Epoch 57/100
# 37/37 [==============================] - 0s 999us/step - loss: 1.0257
# Epoch 58/100
# 37/37 [==============================] - 0s 903us/step - loss: 1.2358
# Epoch 59/100
# 37/37 [==============================] - 0s 959us/step - loss: 1.1737
# Epoch 60/100
# 37/37 [==============================] - 0s 922us/step - loss: 1.2344
# Epoch 61/100
# 37/37 [==============================] - 0s 943us/step - loss: 1.3512
# Epoch 62/100
# 37/37 [==============================] - 0s 999us/step - loss: 0.9458
# Epoch 63/100
# 37/37 [==============================] - 0s 977us/step - loss: 1.0674
# Epoch 64/100
# 37/37 [==============================] - 0s 945us/step - loss: 1.0249
# Epoch 65/100
# 37/37 [==============================] - 0s 917us/step - loss: 1.2015
# Epoch 66/100
# 37/37 [==============================] - 0s 964us/step - loss: 1.0197
# Epoch 67/100
# 37/37 [==============================] - 0s 947us/step - loss: 1.0780
# Epoch 68/100
# 37/37 [==============================] - 0s 966us/step - loss: 1.2430
# Epoch 69/100
# 37/37 [==============================] - 0s 944us/step - loss: 1.0718
# Epoch 70/100
# 37/37 [==============================] - 0s 946us/step - loss: 0.9465
# Epoch 71/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.3197
# Epoch 72/100
# 37/37 [==============================] - 0s 930us/step - loss: 0.9116
# Epoch 73/100
# 37/37 [==============================] - 0s 922us/step - loss: 1.0840
# Epoch 74/100
# 37/37 [==============================] - 0s 931us/step - loss: 1.0624
# Epoch 75/100
# 37/37 [==============================] - 0s 935us/step - loss: 0.9807
# Epoch 76/100
# 37/37 [==============================] - 0s 934us/step - loss: 0.9594
# Epoch 77/100
# 37/37 [==============================] - 0s 898us/step - loss: 1.1249
# Epoch 78/100
# 37/37 [==============================] - 0s 931us/step - loss: 1.1630
# Epoch 79/100
# 37/37 [==============================] - 0s 966us/step - loss: 1.1220
# Epoch 80/100
# 37/37 [==============================] - 0s 946us/step - loss: 1.1607
# Epoch 81/100
# 37/37 [==============================] - 0s 933us/step - loss: 1.2926
# Epoch 82/100
# 37/37 [==============================] - 0s 896us/step - loss: 1.0479
# Epoch 83/100
# 37/37 [==============================] - 0s 987us/step - loss: 1.0421
# Epoch 84/100
# 37/37 [==============================] - 0s 960us/step - loss: 1.1300
# Epoch 85/100
# 37/37 [==============================] - 0s 998us/step - loss: 1.0637
# Epoch 86/100
# 37/37 [==============================] - 0s 984us/step - loss: 1.0263
# Epoch 87/100
# 37/37 [==============================] - 0s 980us/step - loss: 1.0650
# Epoch 88/100
# 37/37 [==============================] - 0s 954us/step - loss: 1.0766
# Epoch 89/100
# 37/37 [==============================] - 0s 939us/step - loss: 0.9820
# Epoch 90/100
# 37/37 [==============================] - 0s 956us/step - loss: 0.9062
# Epoch 91/100
# 37/37 [==============================] - 0s 1ms/step - loss: 1.5514
# Epoch 92/100
# 37/37 [==============================] - 0s 990us/step - loss: 1.0586
# Epoch 93/100
# 37/37 [==============================] - 0s 947us/step - loss: 1.2007
# Epoch 94/100
# 37/37 [==============================] - 0s 940us/step - loss: 0.9997
# Epoch 95/100
# 37/37 [==============================] - 0s 938us/step - loss: 0.9681
# Epoch 96/100
# 37/37 [==============================] - 0s 966us/step - loss: 0.9912
# Epoch 97/100
# 37/37 [==============================] - 0s 975us/step - loss: 0.9671
# Epoch 98/100
# 37/37 [==============================] - 0s 957us/step - loss: 0.9815
# Epoch 99/100
# 37/37 [==============================] - 0s 941us/step - loss: 1.0632
# Epoch 100/100
# 37/37 [==============================] - 0s 923us/step - loss: 1.3261
# /tmp/ipykernel_2227799/510586978.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim((0, 10))
# Train loss: 0.9018490314483643
# Test loss: 0.9627524018287659
# dO18 RMSE: 0.9458739225287979
# EXPECTED:
#     d18O_cel_mean  d18O_cel_variance
# 0          26.130            0.19025
# 1          26.984            0.40123
# 2          24.656            0.17728
# 3          26.356            0.03953
# 4          23.962            0.30992
# 5          24.848            0.15842
# 6          25.080            0.05125
# 7          26.546            2.14378
# 8          25.682            0.94472
# 9          24.028            0.45852
# 10         23.944            0.15813
# 11         23.752            0.52437
# 12         26.018            0.96417
#
# PREDICTED:
#     d18O_cel_mean  d18O_cel_variance
# 0       26.668661           0.829346
# 1       26.668661           0.829346
# 2       25.025976           1.478970
# 3       25.153299           1.433477
# 4       24.897888           1.486126
# 5       23.914268           1.641626
# 6       23.914268           1.641626
# 7       24.897890           1.486123
# 8       25.025972           1.478966
# 9       23.914286           1.641633
# 10      25.197462           0.991562
# 11      24.823051           1.501523
# 12      25.197462           0.991562
# 2023-08-03 16:47:16.151854: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [13,11]
# 	 [[{{node Placeholder/_0}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_random_no_val.tf/assets
# INFO:tensorflow:Assets written to: /usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_random_no_val.tf/assets
# ['/usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_random_no_val_transformer.pkl']

# %% [markdown]
# ### 3) Grouped, fixed, all columns
#
# We can't (easily) generate isoscapes with these because the isoscapes for 'predkrig_br_lat_ISORG', 'Iso_Oxi_Stack_mean_TERZER',
#                    'isoscape_fullmodel_d18O_prec_REGRESSION' are not easily retrievable... but I'm curious how much better the model is if these columns are included.

# %%
grouped_fixed_fileset = {
    'TRAIN' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_train_fixed_grouped.csv'),
    'TEST' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_test_fixed_grouped.csv'),
    'VALIDATION' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_validation_fixed_grouped.csv'),
}

columns_to_normalize = []
columns_to_standardize = [
                   'lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA',
                   'Mean Annual Temperature','Mean Annual Precipitation',
                   'Iso_Oxi_Stack_mean_TERZER',
                   'isoscape_fullmodel_d18O_prec_REGRESSION',
                   'ordinary_kriging_linear_d18O_predicted_variance',
                   'ordinary_kriging_linear_d18O_predicted_mean']

data = load_and_scale(grouped_fixed_fileset, columns_to_normalize, columns_to_standardize)
model = train_and_evaluate(data, "grouped_fixed_all", training_batch_size=3)
model.save(get_model_save_location("kriging_all_fixed.tf"), save_format='tf')
dump(data.feature_scaler, get_model_save_location('kriging_all_fixed_transformer.pkl'))
# Out:
# ==================
# grouped_fixed_all
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 13)]         0           []
#
#  dense_4 (Dense)                (None, 20)           280         ['input_3[0][0]']
#
#  dense_5 (Dense)                (None, 20)           420         ['dense_4[0][0]']
#
#  var_output (Dense)             (None, 1)            21          ['dense_5[0][0]']
#
#  mean_output (Dense)            (None, 1)            21          ['dense_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 1)           0           ['var_output[0][0]']
#  )
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1)           0           ['mean_output[0][0]']
#  )
#
#  tf.__operators__.add_5 (TFOpLa  (None, 1)           0           ['tf.math.multiply_5[0][0]']
#  mbda)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 1)           0           ['tf.math.multiply_4[0][0]']
#  mbda)
#
#  lambda_2 (Lambda)              (None, 1)            0           ['tf.__operators__.add_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 2)            0           ['tf.__operators__.add_4[0][0]',
#                                                                   'lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 742
# Trainable params: 742
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 532.
# Epoch 1532: early stopping
# /tmp/ipykernel_3491701/2845868585.py:9: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim((0, 10))
# Val loss: 0.9783011078834534
# Train loss: 1.0523344278335571
# Test loss: 2.008915901184082
# dO18 RMSE: 1.8347231059040345
# EXPECTED:
#     d18O_cel_mean  d18O_cel_variance
# 0       24.042000           0.345970
# 1       25.240000           0.035950
# 2       25.782000           0.372220
# 3       25.076000           0.230280
# 4       25.966000           0.172480
# 5       27.434000           0.501030
# 6       28.156000           0.999030
# 7       26.836000           0.120880
# 8       28.180000           0.778250
# 9       26.834000           0.094930
# 10      26.644000           0.488430
# 11      26.772000           0.373370
# 12      27.684280           1.216389
# 13      27.403235           0.892280
# 14      24.777670           0.736571
# 15      25.551850           0.312355
# 16      25.115885           0.033519
# 17      25.987815           5.280825
# 18      24.132031           0.389042
# 19      24.898000           0.236070
# 20      23.944000           0.158130
# 21      26.018000           0.964170
#
# PREDICTED:
#     d18O_cel_mean  d18O_cel_variance
# 0       26.041576           1.263573
# 1       26.041576           1.263573
# 2       26.041576           1.263573
# 3       26.041576           1.263573
# 4       26.041576           1.263573
# 5       29.902359           1.941671
# 6       29.837017           1.928721
# 7       29.837017           1.928721
# 8       29.837017           1.928721
# 9       29.837017           1.928721
# 10      29.837017           1.928721
# 11      29.837017           1.928721
# 12      29.902359           1.941671
# 13      29.837017           1.928721
# 14      24.931744           2.550427
# 15      24.871628           3.049239
# 16      24.930983           3.027121
# 17      24.774248           3.085699
# 18      24.898464           3.037338
# 19      26.041576           1.263573
# 20      26.041576           1.263573
# 21      26.041576           1.263573
# 2023-08-03 13:31:51.273361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [22,13]
# 	 [[{{node Placeholder/_0}}]]
# ['variational/model/kriging_all_fixed_transformer.pkl']

# %% [markdown]
# ## 4) Grouped fixed, ablating other columns besides krigin

# %%
grouped_fixed_fileset = {
    'TRAIN' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_train_fixed_grouped.csv'),
    'TEST' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_test_fixed_grouped.csv'),
    'VALIDATION' : os.path.join(FP_ROOT, 'amazon_sample_data/canonical/uc_davis_validation_fixed_grouped.csv'),
}

columns_to_normalize = []
columns_to_standardize = [ 'lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA',
                   'Mean Annual Temperature','Mean Annual Precipitation',
                   'ordinary_kriging_linear_d18O_predicted_variance',
                   'ordinary_kriging_linear_d18O_predicted_mean']

data = load_and_scale(grouped_fixed_fileset, columns_to_normalize, columns_to_standardize)
model = train_and_evaluate(data, "grouped_fixed_ablated_no_val", training_batch_size=3)
model.save(get_model_save_location("kriging_ablated_fixed_no_val.tf"), save_format='tf')
dump(data.feature_scaler, get_model_save_location('kriging_ablated_fixed_no_val_transformer.pkl'))
# Out:
# Streaming output truncated to the last 5000 lines.
# 34/34 [==============================] - 0s 906us/step - loss: 1.6556
# Epoch 2502/5000
# 34/34 [==============================] - 0s 877us/step - loss: 1.3244
# Epoch 2503/5000
# 34/34 [==============================] - 0s 879us/step - loss: 1.1464
# Epoch 2504/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.7177
# Epoch 2505/5000
# 34/34 [==============================] - 0s 907us/step - loss: 1.6035
# Epoch 2506/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.6906
# Epoch 2507/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.5591
# Epoch 2508/5000
# 34/34 [==============================] - 0s 931us/step - loss: 1.2715
# Epoch 2509/5000
# 34/34 [==============================] - 0s 923us/step - loss: 1.4963
# Epoch 2510/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.3236
# Epoch 2511/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.5822
# Epoch 2512/5000
# 34/34 [==============================] - 0s 917us/step - loss: 1.1898
# Epoch 2513/5000
# 34/34 [==============================] - 0s 901us/step - loss: 1.9084
# Epoch 2514/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.0682
# Epoch 2515/5000
# 34/34 [==============================] - 0s 934us/step - loss: 1.4864
# Epoch 2516/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4467
# Epoch 2517/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.8987
# Epoch 2518/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.6727
# Epoch 2519/5000
# 34/34 [==============================] - 0s 929us/step - loss: 1.1281
# Epoch 2520/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.3011
# Epoch 2521/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.1888
# Epoch 2522/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2312
# Epoch 2523/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.7804
# Epoch 2524/5000
# 34/34 [==============================] - 0s 979us/step - loss: 1.3497
# Epoch 2525/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3634
# Epoch 2526/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.4406
# Epoch 2527/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4143
# Epoch 2528/5000
# 34/34 [==============================] - 0s 944us/step - loss: 1.5016
# Epoch 2529/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5786
# Epoch 2530/5000
# 34/34 [==============================] - 0s 969us/step - loss: 1.3692
# Epoch 2531/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3591
# Epoch 2532/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.4257
# Epoch 2533/5000
# 34/34 [==============================] - 0s 957us/step - loss: 2.3330
# Epoch 2534/5000
# 34/34 [==============================] - 0s 992us/step - loss: 1.0905
# Epoch 2535/5000
# 34/34 [==============================] - 0s 924us/step - loss: 1.4184
# Epoch 2536/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3311
# Epoch 2537/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 3.2633
# Epoch 2538/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1282
# Epoch 2539/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.7884
# Epoch 2540/5000
# 34/34 [==============================] - 0s 906us/step - loss: 1.4549
# Epoch 2541/5000
# 34/34 [==============================] - 0s 944us/step - loss: 1.5077
# Epoch 2542/5000
# 34/34 [==============================] - 0s 920us/step - loss: 2.3307
# Epoch 2543/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.5403
# Epoch 2544/5000
# 34/34 [==============================] - 0s 993us/step - loss: 2.6986
# Epoch 2545/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1725
# Epoch 2546/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4456
# Epoch 2547/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5682
# Epoch 2548/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3816
# Epoch 2549/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.3682
# Epoch 2550/5000
# 34/34 [==============================] - 0s 896us/step - loss: 1.4693
# Epoch 2551/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.3875
# Epoch 2552/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.0636
# Epoch 2553/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4429
# Epoch 2554/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.3258
# Epoch 2555/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.1561
# Epoch 2556/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3963
# Epoch 2557/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.7621
# Epoch 2558/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1365
# Epoch 2559/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.8655
# Epoch 2560/5000
# 34/34 [==============================] - 0s 912us/step - loss: 1.3633
# Epoch 2561/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2350
# Epoch 2562/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1364
# Epoch 2563/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2596
# Epoch 2564/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1940
# Epoch 2565/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.9164
# Epoch 2566/5000
# 34/34 [==============================] - 0s 932us/step - loss: 1.4310
# Epoch 2567/5000
# 34/34 [==============================] - 0s 968us/step - loss: 1.1957
# Epoch 2568/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.4575
# Epoch 2569/5000
# 34/34 [==============================] - 0s 931us/step - loss: 1.2611
# Epoch 2570/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.6349
# Epoch 2571/5000
# 34/34 [==============================] - 0s 972us/step - loss: 1.5673
# Epoch 2572/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.2523
# Epoch 2573/5000
# 34/34 [==============================] - 0s 985us/step - loss: 1.0319
# Epoch 2574/5000
# 34/34 [==============================] - 0s 985us/step - loss: 1.4156
# Epoch 2575/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.1462
# Epoch 2576/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.2777
# Epoch 2577/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.6106
# Epoch 2578/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.3152
# Epoch 2579/5000
# 34/34 [==============================] - 0s 887us/step - loss: 1.5949
# Epoch 2580/5000
# 34/34 [==============================] - 0s 980us/step - loss: 1.2771
# Epoch 2581/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.5630
# Epoch 2582/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.5143
# Epoch 2583/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.4115
# Epoch 2584/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5263
# Epoch 2585/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.4556
# Epoch 2586/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.2090
# Epoch 2587/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.6460
# Epoch 2588/5000
# 34/34 [==============================] - 0s 941us/step - loss: 1.8529
# Epoch 2589/5000
# 34/34 [==============================] - 0s 951us/step - loss: 1.2884
# Epoch 2590/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.5290
# Epoch 2591/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.4637
# Epoch 2592/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.5631
# Epoch 2593/5000
# 34/34 [==============================] - 0s 955us/step - loss: 1.6332
# Epoch 2594/5000
# 34/34 [==============================] - 0s 958us/step - loss: 2.1959
# Epoch 2595/5000
# 34/34 [==============================] - 0s 929us/step - loss: 1.4719
# Epoch 2596/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.6946
# Epoch 2597/5000
# 34/34 [==============================] - 0s 946us/step - loss: 1.9170
# Epoch 2598/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.6308
# Epoch 2599/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.3613
# Epoch 2600/5000
# 34/34 [==============================] - 0s 964us/step - loss: 1.2585
# Epoch 2601/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.6398
# Epoch 2602/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.2982
# Epoch 2603/5000
# 34/34 [==============================] - 0s 897us/step - loss: 1.4155
# Epoch 2604/5000
# 34/34 [==============================] - 0s 914us/step - loss: 1.5603
# Epoch 2605/5000
# 34/34 [==============================] - 0s 941us/step - loss: 1.4121
# Epoch 2606/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.2642
# Epoch 2607/5000
# 34/34 [==============================] - 0s 870us/step - loss: 2.4820
# Epoch 2608/5000
# 34/34 [==============================] - 0s 849us/step - loss: 1.3950
# Epoch 2609/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0164
# Epoch 2610/5000
# 34/34 [==============================] - 0s 901us/step - loss: 1.5293
# Epoch 2611/5000
# 34/34 [==============================] - 0s 927us/step - loss: 1.2650
# Epoch 2612/5000
# 34/34 [==============================] - 0s 897us/step - loss: 1.4044
# Epoch 2613/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5258
# Epoch 2614/5000
# 34/34 [==============================] - 0s 987us/step - loss: 1.0619
# Epoch 2615/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4795
# Epoch 2616/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0691
# Epoch 2617/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 3.3839
# Epoch 2618/5000
# 34/34 [==============================] - 0s 920us/step - loss: 1.4870
# Epoch 2619/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2418
# Epoch 2620/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.1677
# Epoch 2621/5000
# 34/34 [==============================] - 0s 946us/step - loss: 1.5868
# Epoch 2622/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.3470
# Epoch 2623/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1553
# Epoch 2624/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.4047
# Epoch 2625/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1437
# Epoch 2626/5000
# 34/34 [==============================] - 0s 940us/step - loss: 1.9461
# Epoch 2627/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2510
# Epoch 2628/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1698
# Epoch 2629/5000
# 34/34 [==============================] - 0s 998us/step - loss: 1.3529
# Epoch 2630/5000
# 34/34 [==============================] - 0s 952us/step - loss: 1.2680
# Epoch 2631/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2740
# Epoch 2632/5000
# 34/34 [==============================] - 0s 987us/step - loss: 2.3783
# Epoch 2633/5000
# 34/34 [==============================] - 0s 972us/step - loss: 1.2936
# Epoch 2634/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4427
# Epoch 2635/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.5601
# Epoch 2636/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5823
# Epoch 2637/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.4719
# Epoch 2638/5000
# 34/34 [==============================] - 0s 962us/step - loss: 1.1798
# Epoch 2639/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.9079
# Epoch 2640/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4316
# Epoch 2641/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3709
# Epoch 2642/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.1791
# Epoch 2643/5000
# 34/34 [==============================] - 0s 998us/step - loss: 1.5628
# Epoch 2644/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.8946
# Epoch 2645/5000
# 34/34 [==============================] - 0s 969us/step - loss: 1.2593
# Epoch 2646/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.2959
# Epoch 2647/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3765
# Epoch 2648/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4986
# Epoch 2649/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.6037
# Epoch 2650/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1690
# Epoch 2651/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.2857
# Epoch 2652/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2322
# Epoch 2653/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6524
# Epoch 2654/5000
# 34/34 [==============================] - 0s 989us/step - loss: 1.9486
# Epoch 2655/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1005
# Epoch 2656/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3558
# Epoch 2657/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.3961
# Epoch 2658/5000
# 34/34 [==============================] - 0s 912us/step - loss: 1.3484
# Epoch 2659/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3007
# Epoch 2660/5000
# 34/34 [==============================] - 0s 963us/step - loss: 3.4998
# Epoch 2661/5000
# 34/34 [==============================] - 0s 992us/step - loss: 1.1494
# Epoch 2662/5000
# 34/34 [==============================] - 0s 934us/step - loss: 1.1046
# Epoch 2663/5000
# 34/34 [==============================] - 0s 927us/step - loss: 1.3039
# Epoch 2664/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.6819
# Epoch 2665/5000
# 34/34 [==============================] - 0s 928us/step - loss: 1.1590
# Epoch 2666/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2356
# Epoch 2667/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.4078
# Epoch 2668/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.3984
# Epoch 2669/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4407
# Epoch 2670/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.6760
# Epoch 2671/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4838
# Epoch 2672/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.2711
# Epoch 2673/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.9486
# Epoch 2674/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3350
# Epoch 2675/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.7039
# Epoch 2676/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.1956
# Epoch 2677/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.1429
# Epoch 2678/5000
# 34/34 [==============================] - 0s 896us/step - loss: 1.5663
# Epoch 2679/5000
# 34/34 [==============================] - 0s 882us/step - loss: 1.3953
# Epoch 2680/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.2798
# Epoch 2681/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.5007
# Epoch 2682/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6936
# Epoch 2683/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.2353
# Epoch 2684/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2359
# Epoch 2685/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.1478
# Epoch 2686/5000
# 34/34 [==============================] - 0s 981us/step - loss: 1.3260
# Epoch 2687/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4870
# Epoch 2688/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.5531
# Epoch 2689/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.5856
# Epoch 2690/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.7055
# Epoch 2691/5000
# 34/34 [==============================] - 0s 916us/step - loss: 1.2646
# Epoch 2692/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3660
# Epoch 2693/5000
# 34/34 [==============================] - 0s 955us/step - loss: 1.5519
# Epoch 2694/5000
# 34/34 [==============================] - 0s 989us/step - loss: 1.2271
# Epoch 2695/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.4198
# Epoch 2696/5000
# 34/34 [==============================] - 0s 981us/step - loss: 1.4205
# Epoch 2697/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.3330
# Epoch 2698/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.4638
# Epoch 2699/5000
# 34/34 [==============================] - 0s 938us/step - loss: 1.5223
# Epoch 2700/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.3713
# Epoch 2701/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3810
# Epoch 2702/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.2620
# Epoch 2703/5000
# 34/34 [==============================] - 0s 952us/step - loss: 1.2588
# Epoch 2704/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.4070
# Epoch 2705/5000
# 34/34 [==============================] - 0s 969us/step - loss: 1.2507
# Epoch 2706/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.4331
# Epoch 2707/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.2578
# Epoch 2708/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.2481
# Epoch 2709/5000
# 34/34 [==============================] - 0s 916us/step - loss: 1.6194
# Epoch 2710/5000
# 34/34 [==============================] - 0s 923us/step - loss: 1.5697
# Epoch 2711/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3022
# Epoch 2712/5000
# 34/34 [==============================] - 0s 979us/step - loss: 1.1749
# Epoch 2713/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.3563
# Epoch 2714/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.3296
# Epoch 2715/5000
# 34/34 [==============================] - 0s 959us/step - loss: 1.3004
# Epoch 2716/5000
# 34/34 [==============================] - 0s 972us/step - loss: 1.3707
# Epoch 2717/5000
# 34/34 [==============================] - 0s 918us/step - loss: 1.4517
# Epoch 2718/5000
# 34/34 [==============================] - 0s 883us/step - loss: 1.7090
# Epoch 2719/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.2795
# Epoch 2720/5000
# 34/34 [==============================] - 0s 986us/step - loss: 1.4284
# Epoch 2721/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.6707
# Epoch 2722/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.1997
# Epoch 2723/5000
# 34/34 [==============================] - 0s 925us/step - loss: 1.2568
# Epoch 2724/5000
# 34/34 [==============================] - 0s 940us/step - loss: 2.0672
# Epoch 2725/5000
# 34/34 [==============================] - 0s 985us/step - loss: 1.9946
# Epoch 2726/5000
# 34/34 [==============================] - 0s 991us/step - loss: 1.2545
# Epoch 2727/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.6648
# Epoch 2728/5000
# 34/34 [==============================] - 0s 962us/step - loss: 1.3463
# Epoch 2729/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.7340
# Epoch 2730/5000
# 34/34 [==============================] - 0s 972us/step - loss: 1.4744
# Epoch 2731/5000
# 34/34 [==============================] - 0s 891us/step - loss: 1.4864
# Epoch 2732/5000
# 34/34 [==============================] - 0s 861us/step - loss: 1.6898
# Epoch 2733/5000
# 34/34 [==============================] - 0s 913us/step - loss: 1.5820
# Epoch 2734/5000
# 34/34 [==============================] - 0s 969us/step - loss: 1.3766
# Epoch 2735/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.8103
# Epoch 2736/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.1661
# Epoch 2737/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.8367
# Epoch 2738/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.7484
# Epoch 2739/5000
# 34/34 [==============================] - 0s 990us/step - loss: 1.3436
# Epoch 2740/5000
# 34/34 [==============================] - 0s 966us/step - loss: 1.3084
# Epoch 2741/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.3327
# Epoch 2742/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4193
# Epoch 2743/5000
# 34/34 [==============================] - 0s 957us/step - loss: 1.2018
# Epoch 2744/5000
# 34/34 [==============================] - 0s 917us/step - loss: 1.2942
# Epoch 2745/5000
# 34/34 [==============================] - 0s 962us/step - loss: 1.1143
# Epoch 2746/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.4280
# Epoch 2747/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.2669
# Epoch 2748/5000
# 34/34 [==============================] - 0s 901us/step - loss: 1.5912
# Epoch 2749/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2470
# Epoch 2750/5000
# 34/34 [==============================] - 0s 889us/step - loss: 1.2896
# Epoch 2751/5000
# 34/34 [==============================] - 0s 958us/step - loss: 1.3698
# Epoch 2752/5000
# 34/34 [==============================] - 0s 903us/step - loss: 1.1407
# Epoch 2753/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.1867
# Epoch 2754/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.3575
# Epoch 2755/5000
# 34/34 [==============================] - 0s 911us/step - loss: 1.7572
# Epoch 2756/5000
# 34/34 [==============================] - 0s 977us/step - loss: 1.4130
# Epoch 2757/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4748
# Epoch 2758/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.0370
# Epoch 2759/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1600
# Epoch 2760/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3795
# Epoch 2761/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.7466
# Epoch 2762/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.3597
# Epoch 2763/5000
# 34/34 [==============================] - 0s 932us/step - loss: 1.5995
# Epoch 2764/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2661
# Epoch 2765/5000
# 34/34 [==============================] - 0s 987us/step - loss: 1.0490
# Epoch 2766/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.8047
# Epoch 2767/5000
# 34/34 [==============================] - 0s 944us/step - loss: 1.0854
# Epoch 2768/5000
# 34/34 [==============================] - 0s 940us/step - loss: 1.3533
# Epoch 2769/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5230
# Epoch 2770/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.5092
# Epoch 2771/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.3282
# Epoch 2772/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.3481
# Epoch 2773/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6772
# Epoch 2774/5000
# 34/34 [==============================] - 0s 994us/step - loss: 1.6842
# Epoch 2775/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3553
# Epoch 2776/5000
# 34/34 [==============================] - 0s 981us/step - loss: 1.5918
# Epoch 2777/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.7600
# Epoch 2778/5000
# 34/34 [==============================] - 0s 918us/step - loss: 1.2607
# Epoch 2779/5000
# 34/34 [==============================] - 0s 913us/step - loss: 1.2257
# Epoch 2780/5000
# 34/34 [==============================] - 0s 922us/step - loss: 1.3340
# Epoch 2781/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.2930
# Epoch 2782/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.3326
# Epoch 2783/5000
# 34/34 [==============================] - 0s 936us/step - loss: 1.2865
# Epoch 2784/5000
# 34/34 [==============================] - 0s 905us/step - loss: 1.3944
# Epoch 2785/5000
# 34/34 [==============================] - 0s 884us/step - loss: 1.2702
# Epoch 2786/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.3685
# Epoch 2787/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.5885
# Epoch 2788/5000
# 34/34 [==============================] - 0s 914us/step - loss: 1.2648
# Epoch 2789/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.8057
# Epoch 2790/5000
# 34/34 [==============================] - 0s 944us/step - loss: 1.5525
# Epoch 2791/5000
# 34/34 [==============================] - 0s 952us/step - loss: 1.6577
# Epoch 2792/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.9185
# Epoch 2793/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.8440
# Epoch 2794/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.2928
# Epoch 2795/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.2865
# Epoch 2796/5000
# 34/34 [==============================] - 0s 997us/step - loss: 2.1768
# Epoch 2797/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4585
# Epoch 2798/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3108
# Epoch 2799/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4935
# Epoch 2800/5000
# 34/34 [==============================] - 0s 981us/step - loss: 1.2137
# Epoch 2801/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.2510
# Epoch 2802/5000
# 34/34 [==============================] - 0s 944us/step - loss: 2.5010
# Epoch 2803/5000
# 34/34 [==============================] - 0s 924us/step - loss: 1.3375
# Epoch 2804/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.1855
# Epoch 2805/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.3652
# Epoch 2806/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.2175
# Epoch 2807/5000
# 34/34 [==============================] - 0s 901us/step - loss: 1.4402
# Epoch 2808/5000
# 34/34 [==============================] - 0s 893us/step - loss: 1.9203
# Epoch 2809/5000
# 34/34 [==============================] - 0s 922us/step - loss: 1.2665
# Epoch 2810/5000
# 34/34 [==============================] - 0s 902us/step - loss: 1.4737
# Epoch 2811/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.7159
# Epoch 2812/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.5725
# Epoch 2813/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.5560
# Epoch 2814/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.8302
# Epoch 2815/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.4350
# Epoch 2816/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.2570
# Epoch 2817/5000
# 34/34 [==============================] - 0s 2ms/step - loss: 0.9887
# Epoch 2818/5000
# 34/34 [==============================] - 0s 936us/step - loss: 1.5020
# Epoch 2819/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.3855
# Epoch 2820/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.6284
# Epoch 2821/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.3162
# Epoch 2822/5000
# 34/34 [==============================] - 0s 932us/step - loss: 1.2773
# Epoch 2823/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.2972
# Epoch 2824/5000
# 34/34 [==============================] - 0s 899us/step - loss: 2.2493
# Epoch 2825/5000
# 34/34 [==============================] - 0s 919us/step - loss: 1.4766
# Epoch 2826/5000
# 34/34 [==============================] - 0s 901us/step - loss: 1.2227
# Epoch 2827/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2709
# Epoch 2828/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1403
# Epoch 2829/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6587
# Epoch 2830/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2047
# Epoch 2831/5000
# 34/34 [==============================] - 0s 959us/step - loss: 2.1753
# Epoch 2832/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.2664
# Epoch 2833/5000
# 34/34 [==============================] - 0s 934us/step - loss: 1.4886
# Epoch 2834/5000
# 34/34 [==============================] - 0s 981us/step - loss: 1.6121
# Epoch 2835/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.4667
# Epoch 2836/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.3947
# Epoch 2837/5000
# 34/34 [==============================] - 0s 931us/step - loss: 1.4021
# Epoch 2838/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.6182
# Epoch 2839/5000
# 34/34 [==============================] - 0s 920us/step - loss: 1.5090
# Epoch 2840/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.2961
# Epoch 2841/5000
# 34/34 [==============================] - 0s 903us/step - loss: 1.2110
# Epoch 2842/5000
# 34/34 [==============================] - 0s 923us/step - loss: 1.5007
# Epoch 2843/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.4683
# Epoch 2844/5000
# 34/34 [==============================] - 0s 997us/step - loss: 1.0712
# Epoch 2845/5000
# 34/34 [==============================] - 0s 951us/step - loss: 1.3442
# Epoch 2846/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.6316
# Epoch 2847/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.4336
# Epoch 2848/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.4628
# Epoch 2849/5000
# 34/34 [==============================] - 0s 952us/step - loss: 1.2914
# Epoch 2850/5000
# 34/34 [==============================] - 0s 986us/step - loss: 1.2310
# Epoch 2851/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2304
# Epoch 2852/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4968
# Epoch 2853/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3476
# Epoch 2854/5000
# 34/34 [==============================] - 0s 999us/step - loss: 1.6796
# Epoch 2855/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3296
# Epoch 2856/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.5056
# Epoch 2857/5000
# 34/34 [==============================] - 0s 953us/step - loss: 1.0694
# Epoch 2858/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.4831
# Epoch 2859/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2579
# Epoch 2860/5000
# 34/34 [==============================] - 0s 932us/step - loss: 1.2891
# Epoch 2861/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5370
# Epoch 2862/5000
# 34/34 [==============================] - 0s 905us/step - loss: 1.5701
# Epoch 2863/5000
# 34/34 [==============================] - 0s 968us/step - loss: 1.3076
# Epoch 2864/5000
# 34/34 [==============================] - 0s 978us/step - loss: 2.0417
# Epoch 2865/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4368
# Epoch 2866/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.4490
# Epoch 2867/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4127
# Epoch 2868/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1355
# Epoch 2869/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.9849
# Epoch 2870/5000
# 34/34 [==============================] - 0s 957us/step - loss: 1.4085
# Epoch 2871/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.2307
# Epoch 2872/5000
# 34/34 [==============================] - 0s 940us/step - loss: 1.5691
# Epoch 2873/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.5124
# Epoch 2874/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.1481
# Epoch 2875/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.5312
# Epoch 2876/5000
# 34/34 [==============================] - 0s 965us/step - loss: 1.3151
# Epoch 2877/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.3587
# Epoch 2878/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.4348
# Epoch 2879/5000
# 34/34 [==============================] - 0s 912us/step - loss: 1.6503
# Epoch 2880/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.2838
# Epoch 2881/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.2176
# Epoch 2882/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.4959
# Epoch 2883/5000
# 34/34 [==============================] - 0s 928us/step - loss: 1.2856
# Epoch 2884/5000
# 34/34 [==============================] - 0s 979us/step - loss: 1.1178
# Epoch 2885/5000
# 34/34 [==============================] - 0s 916us/step - loss: 1.4172
# Epoch 2886/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3321
# Epoch 2887/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3839
# Epoch 2888/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2626
# Epoch 2889/5000
# 34/34 [==============================] - 0s 987us/step - loss: 2.1466
# Epoch 2890/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4843
# Epoch 2891/5000
# 34/34 [==============================] - 0s 966us/step - loss: 1.3146
# Epoch 2892/5000
# 34/34 [==============================] - 0s 960us/step - loss: 1.5647
# Epoch 2893/5000
# 34/34 [==============================] - 0s 965us/step - loss: 1.3367
# Epoch 2894/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.2272
# Epoch 2895/5000
# 34/34 [==============================] - 0s 993us/step - loss: 1.3659
# Epoch 2896/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.3217
# Epoch 2897/5000
# 34/34 [==============================] - 0s 911us/step - loss: 1.1407
# Epoch 2898/5000
# 34/34 [==============================] - 0s 967us/step - loss: 1.3896
# Epoch 2899/5000
# 34/34 [==============================] - 0s 958us/step - loss: 1.3847
# Epoch 2900/5000
# 34/34 [==============================] - 0s 950us/step - loss: 1.3477
# Epoch 2901/5000
# 34/34 [==============================] - 0s 958us/step - loss: 1.3377
# Epoch 2902/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6121
# Epoch 2903/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2096
# Epoch 2904/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3800
# Epoch 2905/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3992
# Epoch 2906/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2487
# Epoch 2907/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1725
# Epoch 2908/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3364
# Epoch 2909/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1805
# Epoch 2910/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4014
# Epoch 2911/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.3491
# Epoch 2912/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3578
# Epoch 2913/5000
# 34/34 [==============================] - 0s 941us/step - loss: 1.2924
# Epoch 2914/5000
# 34/34 [==============================] - 0s 988us/step - loss: 2.1786
# Epoch 2915/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4798
# Epoch 2916/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4582
# Epoch 2917/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6751
# Epoch 2918/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.3891
# Epoch 2919/5000
# 34/34 [==============================] - 0s 936us/step - loss: 1.2532
# Epoch 2920/5000
# 34/34 [==============================] - 0s 985us/step - loss: 1.4386
# Epoch 2921/5000
# 34/34 [==============================] - 0s 976us/step - loss: 1.1380
# Epoch 2922/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2634
# Epoch 2923/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6006
# Epoch 2924/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.4070
# Epoch 2925/5000
# 34/34 [==============================] - 0s 978us/step - loss: 1.3430
# Epoch 2926/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2113
# Epoch 2927/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.3570
# Epoch 2928/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3608
# Epoch 2929/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3528
# Epoch 2930/5000
# 34/34 [==============================] - 0s 955us/step - loss: 1.2968
# Epoch 2931/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4977
# Epoch 2932/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.3254
# Epoch 2933/5000
# 34/34 [==============================] - 0s 892us/step - loss: 1.6818
# Epoch 2934/5000
# 34/34 [==============================] - 0s 914us/step - loss: 1.3085
# Epoch 2935/5000
# 34/34 [==============================] - 0s 906us/step - loss: 1.3756
# Epoch 2936/5000
# 34/34 [==============================] - 0s 969us/step - loss: 1.2841
# Epoch 2937/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.3008
# Epoch 2938/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4191
# Epoch 2939/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1681
# Epoch 2940/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1937
# Epoch 2941/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3781
# Epoch 2942/5000
# 34/34 [==============================] - 0s 972us/step - loss: 2.1299
# Epoch 2943/5000
# 34/34 [==============================] - 0s 968us/step - loss: 1.5211
# Epoch 2944/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2491
# Epoch 2945/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.4846
# Epoch 2946/5000
# 34/34 [==============================] - 0s 989us/step - loss: 2.1040
# Epoch 2947/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.3942
# Epoch 2948/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4153
# Epoch 2949/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2855
# Epoch 2950/5000
# 34/34 [==============================] - 0s 991us/step - loss: 1.3459
# Epoch 2951/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.1873
# Epoch 2952/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.1170
# Epoch 2953/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.1872
# Epoch 2954/5000
# 34/34 [==============================] - 0s 988us/step - loss: 1.4362
# Epoch 2955/5000
# 34/34 [==============================] - 0s 955us/step - loss: 1.5875
# Epoch 2956/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.6214
# Epoch 2957/5000
# 34/34 [==============================] - 0s 946us/step - loss: 1.3757
# Epoch 2958/5000
# 34/34 [==============================] - 0s 889us/step - loss: 1.3051
# Epoch 2959/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2174
# Epoch 2960/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3414
# Epoch 2961/5000
# 34/34 [==============================] - 0s 989us/step - loss: 1.3357
# Epoch 2962/5000
# 34/34 [==============================] - 0s 924us/step - loss: 1.3781
# Epoch 2963/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.2281
# Epoch 2964/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.5856
# Epoch 2965/5000
# 34/34 [==============================] - 0s 998us/step - loss: 1.5918
# Epoch 2966/5000
# 34/34 [==============================] - 0s 979us/step - loss: 1.2363
# Epoch 2967/5000
# 34/34 [==============================] - 0s 941us/step - loss: 1.4889
# Epoch 2968/5000
# 34/34 [==============================] - 0s 992us/step - loss: 1.7170
# Epoch 2969/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4919
# Epoch 2970/5000
# 34/34 [==============================] - 0s 965us/step - loss: 1.1923
# Epoch 2971/5000
# 34/34 [==============================] - 0s 979us/step - loss: 1.4044
# Epoch 2972/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5311
# Epoch 2973/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.4144
# Epoch 2974/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2875
# Epoch 2975/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.0398
# Epoch 2976/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3522
# Epoch 2977/5000
# 34/34 [==============================] - 0s 980us/step - loss: 1.2133
# Epoch 2978/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4995
# Epoch 2979/5000
# 34/34 [==============================] - 0s 986us/step - loss: 1.2687
# Epoch 2980/5000
# 34/34 [==============================] - 0s 966us/step - loss: 1.3821
# Epoch 2981/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3045
# Epoch 2982/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2223
# Epoch 2983/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3838
# Epoch 2984/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2239
# Epoch 2985/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.6844
# Epoch 2986/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4261
# Epoch 2987/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5768
# Epoch 2988/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.9065
# Epoch 2989/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1466
# Epoch 2990/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4734
# Epoch 2991/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3414
# Epoch 2992/5000
# 34/34 [==============================] - 0s 980us/step - loss: 1.8472
# Epoch 2993/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2825
# Epoch 2994/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2055
# Epoch 2995/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1402
# Epoch 2996/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0332
# Epoch 2997/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4236
# Epoch 2998/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1147
# Epoch 2999/5000
# 34/34 [==============================] - 0s 976us/step - loss: 1.2447
# Epoch 3000/5000
# 34/34 [==============================] - 0s 949us/step - loss: 1.0918
# Epoch 3001/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3968
# Epoch 3002/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.1921
# Epoch 3003/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3801
# Epoch 3004/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5156
# Epoch 3005/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0890
# Epoch 3006/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3349
# Epoch 3007/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3776
# Epoch 3008/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4308
# Epoch 3009/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2643
# Epoch 3010/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1507
# Epoch 3011/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3817
# Epoch 3012/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5204
# Epoch 3013/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1752
# Epoch 3014/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5017
# Epoch 3015/5000
# 34/34 [==============================] - 0s 979us/step - loss: 2.1098
# Epoch 3016/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3647
# Epoch 3017/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.8438
# Epoch 3018/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3864
# Epoch 3019/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3025
# Epoch 3020/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3724
# Epoch 3021/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3564
# Epoch 3022/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3465
# Epoch 3023/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0207
# Epoch 3024/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2370
# Epoch 3025/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2856
# Epoch 3026/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3672
# Epoch 3027/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4680
# Epoch 3028/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3560
# Epoch 3029/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2717
# Epoch 3030/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4267
# Epoch 3031/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3762
# Epoch 3032/5000
# 34/34 [==============================] - 0s 944us/step - loss: 1.2594
# Epoch 3033/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.1107
# Epoch 3034/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2985
# Epoch 3035/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3489
# Epoch 3036/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5056
# Epoch 3037/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3330
# Epoch 3038/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4538
# Epoch 3039/5000
# 34/34 [==============================] - 0s 998us/step - loss: 1.3951
# Epoch 3040/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4052
# Epoch 3041/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1987
# Epoch 3042/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4472
# Epoch 3043/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3006
# Epoch 3044/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3414
# Epoch 3045/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2876
# Epoch 3046/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3608
# Epoch 3047/5000
# 34/34 [==============================] - 0s 966us/step - loss: 1.1388
# Epoch 3048/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5873
# Epoch 3049/5000
# 34/34 [==============================] - 0s 985us/step - loss: 1.3811
# Epoch 3050/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5265
# Epoch 3051/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.2814
# Epoch 3052/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.3785
# Epoch 3053/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3053
# Epoch 3054/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2906
# Epoch 3055/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1962
# Epoch 3056/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1889
# Epoch 3057/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1625
# Epoch 3058/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 2.6540
# Epoch 3059/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4204
# Epoch 3060/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.5914
# Epoch 3061/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3721
# Epoch 3062/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1329
# Epoch 3063/5000
# ...
# Epoch 4847/5000
# 34/34 [==============================] - 0s 899us/step - loss: 1.3190
# Epoch 4848/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.4086
# Epoch 4849/5000
# 34/34 [==============================] - 0s 916us/step - loss: 1.3176
# Epoch 4850/5000
# 34/34 [==============================] - 0s 928us/step - loss: 1.2898
# Epoch 4851/5000
# 34/34 [==============================] - 0s 897us/step - loss: 1.3450
# Epoch 4852/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.0114
# Epoch 4853/5000
# 34/34 [==============================] - 0s 918us/step - loss: 1.6336
# Epoch 4854/5000
# 34/34 [==============================] - 0s 904us/step - loss: 1.4815
# Epoch 4855/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.1811
# Epoch 4856/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2994
# Epoch 4857/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9438
# Epoch 4858/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.0789
# Epoch 4859/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3017
# Epoch 4860/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0658
# Epoch 4861/5000
# 34/34 [==============================] - 0s 966us/step - loss: 1.7483
# Epoch 4862/5000
# 34/34 [==============================] - 0s 973us/step - loss: 1.1252
# Epoch 4863/5000
# 34/34 [==============================] - 0s 977us/step - loss: 1.3249
# Epoch 4864/5000
# 34/34 [==============================] - 0s 919us/step - loss: 1.0172
# Epoch 4865/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.3833
# Epoch 4866/5000
# 34/34 [==============================] - 0s 982us/step - loss: 0.9635
# Epoch 4867/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.1330
# Epoch 4868/5000
# 34/34 [==============================] - 0s 918us/step - loss: 1.0280
# Epoch 4869/5000
# 34/34 [==============================] - 0s 909us/step - loss: 1.2830
# Epoch 4870/5000
# 34/34 [==============================] - 0s 889us/step - loss: 1.1233
# Epoch 4871/5000
# 34/34 [==============================] - 0s 880us/step - loss: 1.5271
# Epoch 4872/5000
# 34/34 [==============================] - 0s 872us/step - loss: 1.0885
# Epoch 4873/5000
# 34/34 [==============================] - 0s 866us/step - loss: 1.0388
# Epoch 4874/5000
# 34/34 [==============================] - 0s 856us/step - loss: 1.2448
# Epoch 4875/5000
# 34/34 [==============================] - 0s 936us/step - loss: 1.0959
# Epoch 4876/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.0951
# Epoch 4877/5000
# 34/34 [==============================] - 0s 926us/step - loss: 1.5896
# Epoch 4878/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.0496
# Epoch 4879/5000
# 34/34 [==============================] - 0s 946us/step - loss: 1.0063
# Epoch 4880/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.2351
# Epoch 4881/5000
# 34/34 [==============================] - 0s 932us/step - loss: 1.1255
# Epoch 4882/5000
# 34/34 [==============================] - 0s 890us/step - loss: 1.2059
# Epoch 4883/5000
# 34/34 [==============================] - 0s 894us/step - loss: 1.0252
# Epoch 4884/5000
# 34/34 [==============================] - 0s 849us/step - loss: 1.1392
# Epoch 4885/5000
# 34/34 [==============================] - 0s 914us/step - loss: 1.5199
# Epoch 4886/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0789
# Epoch 4887/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4294
# Epoch 4888/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2975
# Epoch 4889/5000
# 34/34 [==============================] - 0s 970us/step - loss: 1.2523
# Epoch 4890/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2404
# Epoch 4891/5000
# 34/34 [==============================] - 0s 957us/step - loss: 1.0488
# Epoch 4892/5000
# 34/34 [==============================] - 0s 907us/step - loss: 0.9591
# Epoch 4893/5000
# 34/34 [==============================] - 0s 912us/step - loss: 1.0534
# Epoch 4894/5000
# 34/34 [==============================] - 0s 934us/step - loss: 1.2317
# Epoch 4895/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2156
# Epoch 4896/5000
# 34/34 [==============================] - 0s 996us/step - loss: 1.0852
# Epoch 4897/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1943
# Epoch 4898/5000
# 34/34 [==============================] - 0s 924us/step - loss: 1.3718
# Epoch 4899/5000
# 34/34 [==============================] - 0s 879us/step - loss: 1.2550
# Epoch 4900/5000
# 34/34 [==============================] - 0s 863us/step - loss: 1.0064
# Epoch 4901/5000
# 34/34 [==============================] - 0s 909us/step - loss: 1.2232
# Epoch 4902/5000
# 34/34 [==============================] - 0s 900us/step - loss: 1.1745
# Epoch 4903/5000
# 34/34 [==============================] - 0s 860us/step - loss: 1.1236
# Epoch 4904/5000
# 34/34 [==============================] - 0s 902us/step - loss: 1.4285
# Epoch 4905/5000
# 34/34 [==============================] - 0s 945us/step - loss: 1.6215
# Epoch 4906/5000
# 34/34 [==============================] - 0s 996us/step - loss: 1.2566
# Epoch 4907/5000
# 34/34 [==============================] - 0s 900us/step - loss: 1.2288
# Epoch 4908/5000
# 34/34 [==============================] - 0s 896us/step - loss: 1.2842
# Epoch 4909/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.4462
# Epoch 4910/5000
# 34/34 [==============================] - 0s 928us/step - loss: 1.9584
# Epoch 4911/5000
# 34/34 [==============================] - 0s 884us/step - loss: 1.2394
# Epoch 4912/5000
# 34/34 [==============================] - 0s 938us/step - loss: 1.5369
# Epoch 4913/5000
# 34/34 [==============================] - 0s 844us/step - loss: 1.2453
# Epoch 4914/5000
# 34/34 [==============================] - 0s 888us/step - loss: 1.6873
# Epoch 4915/5000
# 34/34 [==============================] - 0s 857us/step - loss: 1.1197
# Epoch 4916/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2911
# Epoch 4917/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.4342
# Epoch 4918/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0233
# Epoch 4919/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3053
# Epoch 4920/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.2112
# Epoch 4921/5000
# 34/34 [==============================] - 0s 976us/step - loss: 1.2041
# Epoch 4922/5000
# 34/34 [==============================] - 0s 959us/step - loss: 1.1059
# Epoch 4923/5000
# 34/34 [==============================] - 0s 982us/step - loss: 1.3490
# Epoch 4924/5000
# 34/34 [==============================] - 0s 937us/step - loss: 1.0437
# Epoch 4925/5000
# 34/34 [==============================] - 0s 975us/step - loss: 1.1357
# Epoch 4926/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.2905
# Epoch 4927/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0636
# Epoch 4928/5000
# 34/34 [==============================] - 0s 975us/step - loss: 0.9834
# Epoch 4929/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.2790
# Epoch 4930/5000
# 34/34 [==============================] - 0s 942us/step - loss: 1.1591
# Epoch 4931/5000
# 34/34 [==============================] - 0s 968us/step - loss: 1.0499
# Epoch 4932/5000
# 34/34 [==============================] - 0s 972us/step - loss: 1.2907
# Epoch 4933/5000
# 34/34 [==============================] - 0s 907us/step - loss: 1.2384
# Epoch 4934/5000
# 34/34 [==============================] - 0s 897us/step - loss: 1.4867
# Epoch 4935/5000
# 34/34 [==============================] - 0s 897us/step - loss: 1.1817
# Epoch 4936/5000
# 34/34 [==============================] - 0s 948us/step - loss: 1.0313
# Epoch 4937/5000
# 34/34 [==============================] - 0s 963us/step - loss: 1.0930
# Epoch 4938/5000
# 34/34 [==============================] - 0s 931us/step - loss: 1.2273
# Epoch 4939/5000
# 34/34 [==============================] - 0s 987us/step - loss: 1.1703
# Epoch 4940/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3244
# Epoch 4941/5000
# 34/34 [==============================] - 0s 974us/step - loss: 1.3338
# Epoch 4942/5000
# 34/34 [==============================] - 0s 938us/step - loss: 1.0531
# Epoch 4943/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1735
# Epoch 4944/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.0886
# Epoch 4945/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0784
# Epoch 4946/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2803
# Epoch 4947/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9537
# Epoch 4948/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1152
# Epoch 4949/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9657
# Epoch 4950/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1766
# Epoch 4951/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.4879
# Epoch 4952/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0797
# Epoch 4953/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2582
# Epoch 4954/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3559
# Epoch 4955/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2081
# Epoch 4956/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.7695
# Epoch 4957/5000
# 34/34 [==============================] - 0s 983us/step - loss: 1.1149
# Epoch 4958/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.3355
# Epoch 4959/5000
# 34/34 [==============================] - 0s 971us/step - loss: 1.5878
# Epoch 4960/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0541
# Epoch 4961/5000
# 34/34 [==============================] - 0s 997us/step - loss: 1.2582
# Epoch 4962/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 0.9803
# Epoch 4963/5000
# 34/34 [==============================] - 0s 970us/step - loss: 1.0948
# Epoch 4964/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0825
# Epoch 4965/5000
# 34/34 [==============================] - 0s 961us/step - loss: 1.2535
# Epoch 4966/5000
# 34/34 [==============================] - 0s 939us/step - loss: 1.0594
# Epoch 4967/5000
# 34/34 [==============================] - 0s 930us/step - loss: 1.1844
# Epoch 4968/5000
# 34/34 [==============================] - 0s 914us/step - loss: 0.9819
# Epoch 4969/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0912
# Epoch 4970/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.1939
# Epoch 4971/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.0629
# Epoch 4972/5000
# 34/34 [==============================] - 0s 933us/step - loss: 1.0784
# Epoch 4973/5000
# 34/34 [==============================] - 0s 962us/step - loss: 1.4121
# Epoch 4974/5000
# 34/34 [==============================] - 0s 964us/step - loss: 1.0752
# Epoch 4975/5000
# 34/34 [==============================] - 0s 914us/step - loss: 1.0801
# Epoch 4976/5000
# 34/34 [==============================] - 0s 943us/step - loss: 1.2327
# Epoch 4977/5000
# 34/34 [==============================] - 0s 910us/step - loss: 1.1285
# Epoch 4978/5000
# 34/34 [==============================] - 0s 896us/step - loss: 1.3483
# Epoch 4979/5000
# 34/34 [==============================] - 0s 902us/step - loss: 0.9457
# Epoch 4980/5000
# 34/34 [==============================] - 0s 885us/step - loss: 1.5434
# Epoch 4981/5000
# 34/34 [==============================] - 0s 1ms/step - loss: 1.2158
# Epoch 4982/5000
# 34/34 [==============================] - 0s 918us/step - loss: 1.0531
# Epoch 4983/5000
# 34/34 [==============================] - 0s 935us/step - loss: 1.0815
# Epoch 4984/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.0419
# Epoch 4985/5000
# 34/34 [==============================] - 0s 956us/step - loss: 1.2574
# Epoch 4986/5000
# 34/34 [==============================] - 0s 891us/step - loss: 1.1682
# Epoch 4987/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.0314
# Epoch 4988/5000
# 34/34 [==============================] - 0s 921us/step - loss: 1.0314
# Epoch 4989/5000
# 34/34 [==============================] - 0s 881us/step - loss: 1.1468
# Epoch 4990/5000
# 34/34 [==============================] - 0s 898us/step - loss: 1.0255
# Epoch 4991/5000
# 34/34 [==============================] - 0s 910us/step - loss: 0.9982
# Epoch 4992/5000
# 34/34 [==============================] - 0s 877us/step - loss: 1.2216
# Epoch 4993/5000
# 34/34 [==============================] - 0s 875us/step - loss: 1.1278
# Epoch 4994/5000
# 34/34 [==============================] - 0s 915us/step - loss: 1.2450
# Epoch 4995/5000
# 34/34 [==============================] - 0s 905us/step - loss: 0.9936
# Epoch 4996/5000
# 34/34 [==============================] - 0s 941us/step - loss: 1.2828
# Epoch 4997/5000
# 34/34 [==============================] - 0s 984us/step - loss: 1.2731
# Epoch 4998/5000
# 34/34 [==============================] - 0s 908us/step - loss: 1.1311
# Epoch 4999/5000
# 34/34 [==============================] - 0s 954us/step - loss: 1.3580
# Epoch 5000/5000
# 34/34 [==============================] - 0s 875us/step - loss: 1.0190
# /tmp/ipykernel_2227799/1437978825.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim((0, 10))
# Train loss: 0.8885728716850281
# Test loss: 3.0278749465942383
# 2023-08-03 16:51:15.194753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [22,11]
# 	 [[{{node Placeholder/_0}}]]
# dO18 RMSE: 2.9020307738827595
# EXPECTED:
#     d18O_cel_mean  d18O_cel_variance
# 0       24.042000           0.345970
# 1       25.240000           0.035950
# 2       25.782000           0.372220
# 3       25.076000           0.230280
# 4       25.966000           0.172480
# 5       27.434000           0.501030
# 6       28.156000           0.999030
# 7       26.836000           0.120880
# 8       28.180000           0.778250
# 9       26.834000           0.094930
# 10      26.644000           0.488430
# 11      26.772000           0.373370
# 12      27.684280           1.216389
# 13      27.403235           0.892280
# 14      24.777670           0.736571
# 15      25.551850           0.312355
# 16      25.115885           0.033519
# 17      25.987815           5.280825
# 18      24.132031           0.389042
# 19      24.898000           0.236070
# 20      23.944000           0.158130
# 21      26.018000           0.964170
#
# PREDICTED:
#     d18O_cel_mean  d18O_cel_variance
# 0       24.439919           0.947839
# 1       24.439919           0.947839
# 2       24.439919           0.947839
# 3       24.439919           0.947839
# 4       24.439919           0.947839
# 5       30.133345           4.448476
# 6       30.155846           4.367300
# 7       30.155846           4.367300
# 8       30.155846           4.367300
# 9       30.155846           4.367300
# 10      30.155846           4.367300
# 11      30.155846           4.367300
# 12      30.133345           4.448476
# 13      30.155846           4.367300
# 14      28.797102           1.771023
# 15      29.812397           1.693465
# 16      29.944353           1.684069
# 17      29.464672           1.719344
# 18      29.849119           1.687898
# 19      24.439919           0.947839
# 20      24.439919           0.947839
# 21      24.439919           0.947839
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_fixed_no_val.tf/assets
# INFO:tensorflow:Assets written to: /usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_fixed_no_val.tf/assets
# ['/usr/local/google/home/ruru/Downloads/model_builds/kriging_ablated_fixed_no_val_transformer.pkl']
