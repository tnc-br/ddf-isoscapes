# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf-isoscapes/blob/new_kl/dnn/variational_with_true_carbon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variational model
#
# Find the mean/variance of O18 ratios (as well as N15 and C13 in the future) at a particular lat/lon across Brazil.

# %%
from collections import defaultdict
import math
import numpy as np
import pandas as pd
import datetime
import os
from typing import List, Tuple, Dict
from dataclasses import dataclass
from joblib import dump


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from matplotlib import pyplot as plt
from tensorflow.python.ops import math_ops
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler
from sklearn.compose import ColumnTransformer

#@title Model training configuration
# See https://zohaib.me/debugging-in-google-collab-notebook/ for tips,
# as well as docs for pdb and ipdb.
DEBUG = False #@param {type:"boolean"}
USE_LOCAL_DRIVE = False #@param {type:"boolean"}
LOCAL_DIR = "/usr/local/google/home/ruru/Downloads/amazon_sample_data-20230712T203059Z-001" #@param
GDRIVE_DIR = "MyDrive/amazon_rainforest_files/" #@param
FP_ROOT = LOCAL_DIR

MODEL_SAVE_LOCATION = "MyDrive/amazon_rainforest_files/variational/model" #@param

def get_model_save_location(filename) -> str:
  root = '' if USE_LOCAL_DRIVE else '/content/gdrive'
  return os.path.join(root, MODEL_SAVE_LOCATION, filename)

# Access data stored on Google Drive if not reading data locally.
if not USE_LOCAL_DRIVE:
  from google.colab import drive
  drive.mount('/content/gdrive')
  global FP_ROOT
  FP_ROOT = os.path.join('/content/gdrive', GDRIVE_DIR)

MODEL_NAME = "truec_model" #@param

TRAINING_SET_PATH = 'amazon_sample_data/canonical/2023_07_27_random_train_random_grouped.csv' #@param
VALIDATION_SET_PATH = 'amazon_sample_data/canonical/2023_07_27_random_validation_random_grouped.csv' #@param
TEST_SET_PATH = 'amazon_sample_data/canonical/2023_07_27_random_test_random_grouped.csv' #@param

TRAINING_COLUMNS_TO_STANDARDIZE = ['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA', 'Mean Annual Temperature', 'Mean Annual Precipitation', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION', 'brisoscape_mean_ISORIX', 'd13C_cel_mean', 'd13C_cel_var', 'ordinary_kriging_linear_d18O_predicted_mean', 'ordinary_kriging_linear_d18O_predicted_variance'] #@param
TRAINING_COLUMNS_TO_SCALE = [] #@param
TRAINING_COLUMNS_TO_PASSTHROUGH = []

MEAN_LABEL_TO_PREDICT = 'd18O_mean' #@param
VARIANCE_LABEL_TO_PREDICT = 'd18O_variance' #@param

if DEBUG:
    # %pip install -Uqq ipdb
    import ipdb
    # %pdb on
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Import libraries required

# %%
import sys

# !if [ ! -d "/content/ddf_common_stub" ] ; then git clone -b test https://github.com/tnc-br/ddf_common_stub.git; fi
sys.path.append("/content/ddf_common_stub/")
import ddfimport
ddfimport.ddf_import_common()
# Out:
# executing checkout_branch ...
# b''
# main branch checked out as readonly. You may now use ddf_common imports

# %%
import raster
import importlib
import dataset
import model
importlib.reload(raster)
importlib.reload(dataset)
# Out:
# <module 'dataset' from '/tmp/ddf_common/dataset.py'>

# %%
def rename_cols(df):
  print(df.columns)
  return df.rename(columns={
    'vpd': 'VPD',
    'rh': 'RH',
    'pet': 'PET',
    'dem': 'DEM',
    'pa': 'PA',
    'isorix': 'brisoscape_mean_ISORIX',
    'MAT': 'Mean Annual Temperature',
    'MAP': 'Mean Annual Precipitation'})

# %% [markdown]
# # Data preparation

# %% [markdown]
# Data nudging for coordinates that are slightly outside the bounds of our rasters.

# %%
def load_dataset(path: str, columns_to_keep: List[str], side_raster_input):
  df = pd.read_csv(path, encoding="ISO-8859-1", sep=',')
  df = df[df[VARIANCE_LABEL_TO_PREDICT].notna()]
  df = rename_cols(df)

  df = dataset.nudge_invalid_coords(
      df, list(side_raster_input.values()), max_degrees_deviation=2)

  for name, geotiff in side_raster_input.items():
    df[name] = df.apply(lambda row: geotiff.value_at(row['long'], row['lat']), axis=1)
  for name, geotiff in side_raster_input.items():
    df = df[df[name].notnull()]

  df['d13C_cel_mean'] = df['d13C_cel'].fillna(df['d13C_cel_mean_artificial'])

  X = df.drop(df.columns.difference(columns_to_keep), axis=1)
  Y = df[[MEAN_LABEL_TO_PREDICT, VARIANCE_LABEL_TO_PREDICT]]

  return X, Y

# %% [markdown]
# # Standardization

# %%
@dataclass
class FeaturesToLabels:
  def __init__(self, X: pd.DataFrame, Y: pd.DataFrame):
    self.X = X
    self.Y = Y

  def as_tuple(self):
    return (self.X, self.Y)


def create_feature_scaler(X: pd.DataFrame,
                          columns_to_passthrough,
                          columns_to_scale,
                          columns_to_standardize) -> ColumnTransformer:
  feature_scaler = ColumnTransformer(
      [(column+'_scaler', MinMaxScaler(), [column]) for column in columns_to_scale] +
      [(column+'_standardizer', StandardScaler(), [column]) for column in columns_to_standardize],
      remainder='passthrough')
  feature_scaler.fit(X)
  return feature_scaler

def create_label_scaler(Y: pd.DataFrame) -> ColumnTransformer:
  label_scaler = ColumnTransformer([
      ('var_minmax_scaler', MinMaxScaler(), [VARIANCE_LABEL_TO_PREDICT]),
      ('mean_std_scaler', StandardScaler(), [MEAN_LABEL_TO_PREDICT])],
      remainder='passthrough')
  label_scaler.fit(Y)
  return label_scaler

def scale(X: pd.DataFrame, feature_scaler):
  # transform() outputs numpy arrays :(  need to convert back to DataFrame.
  X_standardized = pd.DataFrame(feature_scaler.transform(X),
                        index=X.index, columns=X.columns)
  return X_standardized

# %%
# Just a class organization, holds each scaled dataset and the scaler used.
# Useful for unscaling predictions.
@dataclass
class ScaledPartitions():
  def __init__(self,
               feature_scaler: ColumnTransformer,
               label_scaler: ColumnTransformer,
               train: FeaturesToLabels, val: FeaturesToLabels,
               test: FeaturesToLabels):
    self.feature_scaler = feature_scaler
    self.label_scaler = label_scaler
    self.train = train
    self.val = val
    self.test = test


def load_and_scale(config: Dict,
                   columns_to_passthrough: List[str],
                   columns_to_scale: List[str],
                   columns_to_standardize: List[str],
                   extra_columns_from_geotiffs: Dict[str, raster.AmazonGeoTiff]) -> ScaledPartitions:
  columns_to_keep = columns_to_passthrough + columns_to_scale + columns_to_standardize
  X_train, Y_train = load_dataset(config['TRAIN'], columns_to_keep, extra_columns_from_geotiffs)
  X_val, Y_val = load_dataset(config['VALIDATION'], columns_to_keep, extra_columns_from_geotiffs)
  X_test, Y_test = load_dataset(config['TEST'], columns_to_keep, extra_columns_from_geotiffs)

  # Fit the scaler:
  feature_scaler = create_feature_scaler(
      X_train,
      columns_to_passthrough,
      columns_to_scale,
      columns_to_standardize)
  label_scaler = create_label_scaler(Y_train)

  # Apply the scaler:
  train = FeaturesToLabels(scale(X_train, feature_scaler), Y_train)
  val = FeaturesToLabels(scale(X_val, feature_scaler), Y_val)
  test = FeaturesToLabels(scale(X_test, feature_scaler), Y_test)
  return ScaledPartitions(feature_scaler, label_scaler, train, val, test)

# %% [markdown]
# # Model Definition

# %% [markdown]
# The KL Loss function:

# %%
def sample_normal_distribution(
    mean: tf.Tensor,
    stdev: tf.Tensor,
    n: int) -> tf.Tensor:
    '''
    Given a batch of normal distributions described by a mean and stdev in
    a tf.Tensor, sample n elements from each distribution and return the mean
    and standard deviation per sample.
    '''
    batch_size = tf.shape(mean)[0]

    # Output tensor is (n, batch_size, 1)
    sample_values = tfp.distributions.Normal(
        loc=mean,
        scale=stdev).sample(
            sample_shape=n)
    # Reshaped tensor will be (batch_size, n)
    sample_values = tf.transpose(sample_values)
    # Get the mean per sample in the batch.
    sample_mean = tf.transpose(tf.math.reduce_mean(sample_values, 2))
    sample_stdev = tf.transpose(tf.math.reduce_std(sample_values, 2))

    return sample_mean, sample_stdev

import tensorflow_probability as tfp

# log(σ2/σ1) + ( σ1^2+(μ1−μ2)^2 ) / 2* σ^2   − 1/2
def kl_divergence_helper(real, predicted, sample):
    '''
    real: tf.Tensor of the real mean and standard deviation of sample to compare
    predicted: tf.Tensor of the predicted mean and standard deviation to compare
    sample: Whether or not to sample the predicted distribution to get a new
            mean and standard deviation.
    '''
    if real.shape != predicted.shape:
      raise ValueError(
          f"real.shape {real.shape} != predicted.shape {predicted.shape}")

    real_value = tf.gather(real, [0], axis=1)
    real_std = tf.math.sqrt(tf.gather(real, [1], axis=1))


    predicted_value = tf.gather(predicted, [0], axis=1)
    predicted_std = tf.math.sqrt(tf.gather(predicted, [1], axis=1))
    # If true, sample from the distribution defined by the predicted mean and
    # standard deviation to use for mean and stdev used in KL divergence loss.
    if sample:
      predicted_value, predicted_std = sample_normal_distribution(
          mean=predicted_value, stdev=predicted_std, n=50)

    kl_loss = -0.5 + tf.math.log(predicted_std/real_std) + \
     (tf.square(real_std) + tf.square(real_value - predicted_value))/ \
     (2*tf.square(predicted_std))

    return tf.math.reduce_mean(kl_loss)

def kl_divergence(real, predicted):
  return kl_divergence_helper(real, predicted, True)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

def get_early_stopping_callback():
  return EarlyStopping(monitor='val_loss', patience=1000, min_delta=0.001,
                       verbose=1, restore_best_weights=True, start_from_epoch=0)

tf.keras.utils.set_random_seed(18731)

# I was experimenting with models that took longer to train, and used this
# checkpointing callback to periodically save the model. It's optional.
def get_checkpoint_callback(model_file):
  return ModelCheckpoint(
      get_model_save_location(model_file),
      monitor='val_loss', verbose=0, save_best_only=True, mode='min')

def train_or_update_variational_model(
        sp: ScaledPartitions,
        hidden_layers: List[int],
        epochs: int,
        batch_size: int,
        lr: float,
        model_file=None,
        use_checkpoint=False):
  callbacks_list = [get_early_stopping_callback(),
                    get_checkpoint_callback(model_file)]
  if not use_checkpoint:
    inputs = keras.Input(shape=(sp.train.X.shape[1],))
    x = inputs
    for layer_size in hidden_layers:
      x = keras.layers.Dense(
          layer_size, activation='relu')(x)
    mean_output = keras.layers.Dense(
        1, name='mean_output')(x)

    # We can not have negative variance. Apply very little variance.
    var_output = keras.layers.Dense(
        1, name='var_output')(x)

    # Invert the normalization on our outputs
    mean_scaler = sp.label_scaler.named_transformers_['mean_std_scaler']
    untransformed_mean = mean_output * mean_scaler.var_ + mean_scaler.mean_

    var_scaler = sp.label_scaler.named_transformers_['var_minmax_scaler']
    unscaled_var = var_output * var_scaler.scale_ + var_scaler.min_
    untransformed_var = keras.layers.Lambda(lambda t: tf.math.log(1 + tf.exp(t)))(unscaled_var)

    # Output mean,  tuples.
    outputs = keras.layers.concatenate([untransformed_mean, untransformed_var])
    model = keras.Model(inputs=inputs, outputs=outputs)

    optimizer = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=optimizer, loss=kl_divergence)
    model.summary()
  else:
    model = keras.models.load_model(
        get_model_save_location(model_file),
        custom_objects={"kl_divergence": kl_divergence})
  history = model.fit(sp.train.X, sp.train.Y, verbose=1, validation_data=sp.val.as_tuple(), shuffle=True,
                      epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)
  return history, model

# %%
from sklearn.metrics import mean_squared_error

def render_plot_loss(history, name):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title(name + ' model loss')
  plt.ylabel('loss')
  plt.yscale("log")
  plt.ylim((0, 10))
  plt.xlabel('epoch')
  plt.legend(['loss', 'val_loss'], loc='upper left')
  plt.show()

def train_and_evaluate(sp: ScaledPartitions, run_id: str, training_batch_size=5):
  print("==================")
  print(run_id)
  history, model = train_or_update_variational_model(
      sp, hidden_layers=[20, 20], epochs=5000, batch_size=training_batch_size,
      lr=0.00001, model_file=run_id+".h5", use_checkpoint=False)
  render_plot_loss(history, run_id+" kl_loss")
  model.save(get_model_save_location(run_id+".h5"), save_format="h5")

  best_epoch_index = history.history['val_loss'].index(min(history.history['val_loss']))
  print('Val loss:', history.history['val_loss'][best_epoch_index])
  print('Train loss:', history.history['loss'][best_epoch_index])
  print('Test loss:', model.evaluate(x=sp.test.X, y=sp.test.Y, verbose=0))

  predictions = model.predict_on_batch(sp.test.X)
  predictions = pd.DataFrame(predictions, columns=[MEAN_LABEL_TO_PREDICT, VARIANCE_LABEL_TO_PREDICT])
  rmse = np.sqrt(mean_squared_error(sp.test.Y[MEAN_LABEL_TO_PREDICT], predictions[MEAN_LABEL_TO_PREDICT]))
  print("dO18 RMSE: "+ str(rmse))
  print("EXPECTED:")
  print(sp.test.Y.to_string())
  print()
  print("PREDICTED:")
  print(predictions.to_string())
  return model

# %% [markdown]
# # Model Training

# %%
grouped_random_fileset = {
    'TRAIN' : os.path.join(FP_ROOT, TRAINING_SET_PATH),
    'TEST' : os.path.join(FP_ROOT, VALIDATION_SET_PATH),
    'VALIDATION' : os.path.join(FP_ROOT, TEST_SET_PATH),
}

# Create artifical columns by querying rasters at each lat/lon in the training
# dataset CSV.
extra_columns_from_geotiffs = {
  "d13C_cel_mean_artificial" : raster.load_raster(raster.get_raster_path("d13C_cel_map_BRAZIL_stack.tiff"), use_only_band_index=0),
  "d13C_cel_var" : raster.load_raster(raster.get_raster_path("d13C_cel_map_BRAZIL_stack.tiff"), use_only_band_index=1),
  "ordinary_kriging_linear_d18O_predicted_mean" : raster.krig_means_isoscape_geotiff(),
  "ordinary_kriging_linear_d18O_predicted_variance" : raster.krig_variances_isoscape_geotiff(),
}

data = load_and_scale(grouped_random_fileset,
                      TRAINING_COLUMNS_TO_PASSTHROUGH,
                      TRAINING_COLUMNS_TO_SCALE,
                      TRAINING_COLUMNS_TO_STANDARDIZE,
                      extra_columns_from_geotiffs)
data.train.X.columns
# Out:
# Driver: GTiff/GeoTIFF
# Size is 235 x 218 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 4.500000000659528)
# Pixel Size = (0.166666666667993, -0.16666666666799657)
# Driver: GTiff/GeoTIFF
# Size is 235 x 218 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 4.500000000659528)
# Pixel Size = (0.166666666667993, -0.16666666666799657)
# Index(['Unnamed: 0', 'Code', 'lat', 'long', 'd13C_cel', 'vpd', 'rh', 'pet',
#        'dem', 'pa', 'MAT', 'MAP', 'isorix', 'Iso_Oxi_Stack_mean_TERZER',
#        'isoscape_fullmodel_d18O_prec_REGRESSION', 'd18O_count', 'd18O_mean',
#        'd18O_variance'],
#       dtype='object')
# Index(['Unnamed: 0', 'Code', 'lat', 'long', 'd13C_cel', 'vpd', 'rh', 'pet',
#        'dem', 'pa', 'MAT', 'MAP', 'isorix', 'Iso_Oxi_Stack_mean_TERZER',
#        'isoscape_fullmodel_d18O_prec_REGRESSION', 'd18O_count', 'd18O_mean',
#        'd18O_variance'],
#       dtype='object')
# Index(['Unnamed: 0', 'Code', 'lat', 'long', 'd13C_cel', 'vpd', 'rh', 'pet',
#        'dem', 'pa', 'MAT', 'MAP', 'isorix', 'Iso_Oxi_Stack_mean_TERZER',
#        'isoscape_fullmodel_d18O_prec_REGRESSION', 'd18O_count', 'd18O_mean',
#        'd18O_variance'],
#       dtype='object')
# Index(['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA',
#        'Mean Annual Temperature', 'Mean Annual Precipitation',
#        'brisoscape_mean_ISORIX', 'Iso_Oxi_Stack_mean_TERZER',
#        'isoscape_fullmodel_d18O_prec_REGRESSION', 'd13C_cel_var',
#        'ordinary_kriging_linear_d18O_predicted_mean',
#        'ordinary_kriging_linear_d18O_predicted_variance', 'd13C_cel_mean'],
#       dtype='object')

# %%
model = train_and_evaluate(data, MODEL_NAME, training_batch_size=3)
# Out:
# ==================
# truec_model
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 16)]         0           []
#
#  dense_2 (Dense)                (None, 20)           340         ['input_2[0][0]']
#
#  dense_3 (Dense)                (None, 20)           420         ['dense_2[0][0]']
#
#  var_output (Dense)             (None, 1)            21          ['dense_3[0][0]']
#
#  mean_output (Dense)            (None, 1)            21          ['dense_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1)           0           ['var_output[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1)           0           ['mean_output[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1)           0           ['tf.math.multiply_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1)           0           ['tf.math.multiply_2[0][0]']
#  mbda)
#
#  lambda_1 (Lambda)              (None, 1)            0           ['tf.__operators__.add_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 2)            0           ['tf.__operators__.add_2[0][0]',
#                                                                   'lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 802
# Trainable params: 802
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/5000
# 30/30 [==============================] - 2s 15ms/step - loss: 1.4947 - val_loss: 2.6383
# Epoch 2/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.6150 - val_loss: 1.7172
# Epoch 3/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5015 - val_loss: 1.6106
# Epoch 4/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6216 - val_loss: 1.7621
# Epoch 5/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6939 - val_loss: 2.0810
# Epoch 6/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5194 - val_loss: 1.8953
# Epoch 7/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3945 - val_loss: 2.0788
# Epoch 8/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4768 - val_loss: 2.3014
# Epoch 9/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4902 - val_loss: 1.6105
# Epoch 10/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6637 - val_loss: 1.7988
# Epoch 11/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4671 - val_loss: 1.9874
# Epoch 12/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5459 - val_loss: 2.2973
# Epoch 13/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5099 - val_loss: 1.9325
# Epoch 14/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4914 - val_loss: 2.1084
# Epoch 15/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.7149 - val_loss: 1.9562
# Epoch 16/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5822 - val_loss: 2.6531
# Epoch 17/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5285 - val_loss: 1.5925
# Epoch 18/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.7438 - val_loss: 1.6696
# Epoch 19/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.6788 - val_loss: 1.9670
# Epoch 20/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.4642 - val_loss: 1.5154
# Epoch 21/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3668 - val_loss: 1.9205
# Epoch 22/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4056 - val_loss: 2.3665
# Epoch 23/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4458 - val_loss: 1.6569
# Epoch 24/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4726 - val_loss: 1.9546
# Epoch 25/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3946 - val_loss: 1.8334
# Epoch 26/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5227 - val_loss: 1.8754
# Epoch 27/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4773 - val_loss: 1.8974
# Epoch 28/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.5800 - val_loss: 1.4388
# Epoch 29/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2838 - val_loss: 1.8189
# Epoch 30/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3466 - val_loss: 1.7312
# Epoch 31/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.6129 - val_loss: 1.9725
# Epoch 32/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4707 - val_loss: 2.6035
# Epoch 33/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5049 - val_loss: 1.7844
# Epoch 34/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5500 - val_loss: 1.5197
# Epoch 35/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4264 - val_loss: 1.5835
# Epoch 36/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6100 - val_loss: 1.7611
# Epoch 37/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4943 - val_loss: 1.6465
# Epoch 38/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5927 - val_loss: 1.6857
# Epoch 39/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3764 - val_loss: 2.0896
# Epoch 40/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3499 - val_loss: 2.0370
# Epoch 41/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4943 - val_loss: 1.8961
# Epoch 42/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4139 - val_loss: 1.9171
# Epoch 43/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4556 - val_loss: 1.8007
# Epoch 44/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6353 - val_loss: 1.9597
# Epoch 45/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4971 - val_loss: 2.2813
# Epoch 46/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3283 - val_loss: 2.1201
# Epoch 47/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.8605 - val_loss: 1.5467
# Epoch 48/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4785 - val_loss: 1.7878
# Epoch 49/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4038 - val_loss: 1.6231
# Epoch 50/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4987 - val_loss: 1.5721
# Epoch 51/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4893 - val_loss: 1.9134
# Epoch 52/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5021 - val_loss: 1.8957
# Epoch 53/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4866 - val_loss: 2.0727
# Epoch 54/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4875 - val_loss: 1.7724
# Epoch 55/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.7044 - val_loss: 1.4932
# Epoch 56/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4723 - val_loss: 1.6803
# Epoch 57/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3025 - val_loss: 1.3327
# Epoch 58/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4740 - val_loss: 1.7918
# Epoch 59/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4028 - val_loss: 1.6095
# Epoch 60/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3852 - val_loss: 2.6133
# Epoch 61/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3445 - val_loss: 1.5088
# Epoch 62/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3042 - val_loss: 1.8199
# Epoch 63/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2799 - val_loss: 1.7957
# Epoch 64/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2342 - val_loss: 1.4611
# Epoch 65/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5473 - val_loss: 1.8870
# Epoch 66/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2725 - val_loss: 1.3093
# Epoch 67/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.7186 - val_loss: 1.8706
# Epoch 68/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5255 - val_loss: 1.5177
# Epoch 69/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4068 - val_loss: 1.6934
# Epoch 70/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3114 - val_loss: 1.4419
# Epoch 71/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3543 - val_loss: 1.5988
# Epoch 72/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3499 - val_loss: 1.6476
# Epoch 73/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2661 - val_loss: 1.5009
# Epoch 74/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3434 - val_loss: 1.6596
# Epoch 75/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3944 - val_loss: 1.6034
# Epoch 76/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2326 - val_loss: 1.2317
# Epoch 77/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6424 - val_loss: 1.4116
# Epoch 78/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4308 - val_loss: 1.6188
# Epoch 79/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2631 - val_loss: 1.5525
# Epoch 80/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2946 - val_loss: 1.7895
# Epoch 81/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4100 - val_loss: 1.5356
# Epoch 82/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2015 - val_loss: 2.0708
# Epoch 83/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3530 - val_loss: 1.3596
# Epoch 84/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3843 - val_loss: 1.8372
# Epoch 85/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3652 - val_loss: 1.7431
# Epoch 86/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4541 - val_loss: 1.3628
# Epoch 87/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5423 - val_loss: 1.7769
# Epoch 88/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3175 - val_loss: 1.4272
# Epoch 89/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2441 - val_loss: 1.5374
# Epoch 90/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4267 - val_loss: 1.6746
# Epoch 91/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4267 - val_loss: 1.8450
# Epoch 92/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5019 - val_loss: 1.5261
# Epoch 93/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4021 - val_loss: 1.6448
# Epoch 94/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3016 - val_loss: 1.3203
# Epoch 95/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5420 - val_loss: 1.9413
# Epoch 96/5000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3789 - val_loss: 1.3407
# Epoch 97/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3481 - val_loss: 2.1079
# Epoch 98/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4335 - val_loss: 2.3956
# Epoch 99/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3737 - val_loss: 1.5198
# Epoch 100/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3558 - val_loss: 1.6632
# Epoch 101/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5345 - val_loss: 1.8742
# Epoch 102/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2851 - val_loss: 1.5403
# Epoch 103/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4324 - val_loss: 1.3699
# Epoch 104/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2855 - val_loss: 1.8070
# Epoch 105/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4139 - val_loss: 1.5640
# Epoch 106/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2816 - val_loss: 2.0005
# Epoch 107/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3812 - val_loss: 1.5902
# Epoch 108/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3306 - val_loss: 1.4892
# Epoch 109/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2966 - val_loss: 1.5066
# Epoch 110/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2233 - val_loss: 1.6054
# Epoch 111/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2407 - val_loss: 1.4461
# Epoch 112/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2474 - val_loss: 1.5983
# Epoch 113/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3757 - val_loss: 1.5596
# Epoch 114/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2443 - val_loss: 1.5241
# Epoch 115/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2461 - val_loss: 1.5418
# Epoch 116/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5381 - val_loss: 1.3461
# Epoch 117/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2095 - val_loss: 1.2463
# Epoch 118/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2822 - val_loss: 1.4257
# Epoch 119/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1618 - val_loss: 1.3630
# Epoch 120/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5163 - val_loss: 1.5908
# Epoch 121/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3993 - val_loss: 1.2785
# Epoch 122/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3513 - val_loss: 1.4618
# Epoch 123/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1996 - val_loss: 1.4647
# Epoch 124/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2839 - val_loss: 1.4845
# Epoch 125/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.3474 - val_loss: 1.2124
# Epoch 126/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3189 - val_loss: 1.2203
# Epoch 127/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3952 - val_loss: 1.9268
# Epoch 128/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4269 - val_loss: 1.8472
# Epoch 129/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2310 - val_loss: 1.6164
# Epoch 130/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3476 - val_loss: 1.3903
# Epoch 131/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2908 - val_loss: 1.3251
# Epoch 132/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2694 - val_loss: 1.3342
# Epoch 133/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2225 - val_loss: 1.3092
# Epoch 134/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2735 - val_loss: 1.7814
# Epoch 135/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2856 - val_loss: 1.7962
# Epoch 136/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2806 - val_loss: 1.2815
# Epoch 137/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3785 - val_loss: 1.7607
# Epoch 138/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4736 - val_loss: 1.2685
# Epoch 139/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4431 - val_loss: 1.4165
# Epoch 140/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4683 - val_loss: 1.2785
# Epoch 141/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3432 - val_loss: 1.1326
# Epoch 142/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2135 - val_loss: 1.3335
# Epoch 143/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.5029 - val_loss: 1.4471
# Epoch 144/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2300 - val_loss: 1.5068
# Epoch 145/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2669 - val_loss: 1.5073
# Epoch 146/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3636 - val_loss: 1.1959
# Epoch 147/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4230 - val_loss: 1.4559
# Epoch 148/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3492 - val_loss: 1.3503
# Epoch 149/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1975 - val_loss: 1.3729
# Epoch 150/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2021 - val_loss: 1.3238
# Epoch 151/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1869 - val_loss: 1.3600
# Epoch 152/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3306 - val_loss: 1.7559
# Epoch 153/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1580 - val_loss: 1.6286
# Epoch 154/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2605 - val_loss: 1.3120
# Epoch 155/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2322 - val_loss: 1.1500
# Epoch 156/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2008 - val_loss: 1.3027
# Epoch 157/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1639 - val_loss: 1.3657
# Epoch 158/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3533 - val_loss: 1.3690
# Epoch 159/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3719 - val_loss: 1.5657
# Epoch 160/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0994 - val_loss: 1.3675
# Epoch 161/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2989 - val_loss: 1.5572
# Epoch 162/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3172 - val_loss: 1.2020
# Epoch 163/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3674 - val_loss: 1.3855
# Epoch 164/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2978 - val_loss: 1.3181
# Epoch 165/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3686 - val_loss: 1.2553
# Epoch 166/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3585 - val_loss: 1.1911
# Epoch 167/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2339 - val_loss: 1.4448
# Epoch 168/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3635 - val_loss: 2.1975
# Epoch 169/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2894 - val_loss: 1.1629
# Epoch 170/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2340 - val_loss: 1.3298
# Epoch 171/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1407 - val_loss: 1.5478
# Epoch 172/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1091 - val_loss: 1.1280
# Epoch 173/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2481 - val_loss: 1.2251
# Epoch 174/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3356 - val_loss: 1.5628
# Epoch 175/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2506 - val_loss: 1.0233
# Epoch 176/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4878 - val_loss: 1.5996
# Epoch 177/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1721 - val_loss: 1.4328
# Epoch 178/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2428 - val_loss: 1.1929
# Epoch 179/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2750 - val_loss: 1.3556
# Epoch 180/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3136 - val_loss: 1.2910
# Epoch 181/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2412 - val_loss: 1.4514
# Epoch 182/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1803 - val_loss: 1.6115
# Epoch 183/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2637 - val_loss: 1.4849
# Epoch 184/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1819 - val_loss: 1.3282
# Epoch 185/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4030 - val_loss: 1.6947
# Epoch 186/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1884 - val_loss: 1.5186
# Epoch 187/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3741 - val_loss: 1.3113
# Epoch 188/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3593 - val_loss: 1.1893
# Epoch 189/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2744 - val_loss: 1.0307
# Epoch 190/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2377 - val_loss: 1.2485
# Epoch 191/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1624 - val_loss: 1.3052
# Epoch 192/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0573 - val_loss: 1.3667
# Epoch 193/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1924 - val_loss: 1.5891
# Epoch 194/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1227 - val_loss: 1.3565
# Epoch 195/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1588 - val_loss: 1.4076
# Epoch 196/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2956 - val_loss: 1.4917
# Epoch 197/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2408 - val_loss: 1.3136
# Epoch 198/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1346 - val_loss: 0.9566
# Epoch 199/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1687 - val_loss: 1.2541
# Epoch 200/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2402 - val_loss: 1.2753
# Epoch 201/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1416 - val_loss: 1.1499
# Epoch 202/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3139 - val_loss: 1.3575
# Epoch 203/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3779 - val_loss: 1.2704
# Epoch 204/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2815 - val_loss: 1.1519
# Epoch 205/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1908 - val_loss: 1.3393
# Epoch 206/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2261 - val_loss: 1.2480
# Epoch 207/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2452 - val_loss: 1.7193
# Epoch 208/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1666 - val_loss: 1.6259
# Epoch 209/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1689 - val_loss: 1.2983
# Epoch 210/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3075 - val_loss: 1.3507
# Epoch 211/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2393 - val_loss: 1.0953
# Epoch 212/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1136 - val_loss: 1.2911
# Epoch 213/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1800 - val_loss: 2.2234
# Epoch 214/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2451 - val_loss: 1.3385
# Epoch 215/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2106 - val_loss: 1.4126
# Epoch 216/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1594 - val_loss: 1.3696
# Epoch 217/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1294 - val_loss: 1.3627
# Epoch 218/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4156 - val_loss: 1.2417
# Epoch 219/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1199 - val_loss: 1.6895
# Epoch 220/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.4452 - val_loss: 1.3711
# Epoch 221/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1271 - val_loss: 1.2512
# Epoch 222/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3468 - val_loss: 1.2457
# Epoch 223/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2823 - val_loss: 1.2451
# Epoch 224/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3685 - val_loss: 1.3001
# Epoch 225/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.0599 - val_loss: 1.3692
# Epoch 226/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1461 - val_loss: 1.2731
# Epoch 227/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1380 - val_loss: 1.4117
# Epoch 228/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2026 - val_loss: 1.1212
# Epoch 229/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1761 - val_loss: 1.5800
# Epoch 230/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1795 - val_loss: 1.2484
# Epoch 231/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1254 - val_loss: 1.2739
# Epoch 232/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3421 - val_loss: 1.2732
# Epoch 233/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0619 - val_loss: 1.3730
# Epoch 234/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0675 - val_loss: 1.4656
# Epoch 235/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1914 - val_loss: 1.0877
# Epoch 236/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2037 - val_loss: 1.2975
# Epoch 237/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1936 - val_loss: 1.1224
# Epoch 238/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3297 - val_loss: 1.2034
# Epoch 239/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2145 - val_loss: 1.3421
# Epoch 240/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1257 - val_loss: 0.8532
# Epoch 241/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3210 - val_loss: 1.0347
# Epoch 242/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2275 - val_loss: 1.1272
# Epoch 243/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1896 - val_loss: 1.0843
# Epoch 244/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2288 - val_loss: 1.0523
# Epoch 245/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0948 - val_loss: 1.2592
# Epoch 246/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0820 - val_loss: 1.2016
# Epoch 247/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1836 - val_loss: 1.4562
# Epoch 248/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2772 - val_loss: 1.0265
# Epoch 249/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0092 - val_loss: 1.1587
# Epoch 250/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1210 - val_loss: 1.2238
# Epoch 251/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1599 - val_loss: 1.2851
# Epoch 252/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0908 - val_loss: 1.1357
# Epoch 253/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0907 - val_loss: 1.2791
# Epoch 254/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1547 - val_loss: 1.2732
# Epoch 255/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2560 - val_loss: 1.2498
# Epoch 256/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2266 - val_loss: 1.0616
# Epoch 257/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1730 - val_loss: 1.1908
# Epoch 258/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1308 - val_loss: 1.2743
# Epoch 259/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1049 - val_loss: 1.2155
# Epoch 260/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1563 - val_loss: 1.2271
# Epoch 261/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1671 - val_loss: 1.0520
# Epoch 262/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2985 - val_loss: 1.2026
# Epoch 263/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1007 - val_loss: 1.2418
# Epoch 264/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2477 - val_loss: 0.9884
# Epoch 265/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1875 - val_loss: 1.2122
# Epoch 266/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9777 - val_loss: 1.0925
# Epoch 267/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1410 - val_loss: 0.9979
# Epoch 268/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1380 - val_loss: 1.1151
# Epoch 269/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1243 - val_loss: 1.3597
# Epoch 270/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0637 - val_loss: 1.1381
# Epoch 271/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2498 - val_loss: 1.3070
# Epoch 272/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2330 - val_loss: 1.2921
# Epoch 273/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2520 - val_loss: 1.1749
# Epoch 274/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2249 - val_loss: 1.4251
# Epoch 275/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2220 - val_loss: 0.9261
# Epoch 276/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1610 - val_loss: 1.5515
# Epoch 277/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0400 - val_loss: 1.2016
# Epoch 278/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1884 - val_loss: 0.9348
# Epoch 279/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1583 - val_loss: 1.2472
# Epoch 280/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3891 - val_loss: 1.2171
# Epoch 281/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2244 - val_loss: 0.9533
# Epoch 282/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2389 - val_loss: 1.4291
# Epoch 283/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1772 - val_loss: 1.4357
# Epoch 284/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2122 - val_loss: 0.9944
# Epoch 285/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0820 - val_loss: 1.1957
# Epoch 286/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0417 - val_loss: 1.3693
# Epoch 287/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1804 - val_loss: 1.0621
# Epoch 288/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0202 - val_loss: 1.2828
# Epoch 289/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2077 - val_loss: 1.2043
# Epoch 290/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1614 - val_loss: 1.4435
# Epoch 291/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1844 - val_loss: 1.5089
# Epoch 292/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1822 - val_loss: 1.2722
# Epoch 293/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2287 - val_loss: 0.9837
# Epoch 294/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0318 - val_loss: 1.1739
# Epoch 295/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0550 - val_loss: 1.1116
# Epoch 296/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0126 - val_loss: 1.0731
# Epoch 297/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1253 - val_loss: 1.5578
# Epoch 298/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1255 - val_loss: 1.2043
# Epoch 299/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0163 - val_loss: 1.2664
# Epoch 300/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0545 - val_loss: 1.2644
# Epoch 301/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1244 - val_loss: 1.0818
# Epoch 302/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2252 - val_loss: 1.4063
# Epoch 303/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1881 - val_loss: 1.0677
# Epoch 304/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0675 - val_loss: 1.2069
# Epoch 305/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1416 - val_loss: 1.2681
# Epoch 306/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1272 - val_loss: 0.9604
# Epoch 307/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2328 - val_loss: 1.0818
# Epoch 308/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2546 - val_loss: 1.1511
# Epoch 309/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2178 - val_loss: 1.0353
# Epoch 310/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1308 - val_loss: 1.2011
# Epoch 311/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1702 - val_loss: 1.0495
# Epoch 312/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0016 - val_loss: 1.2083
# Epoch 313/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0553 - val_loss: 1.1707
# Epoch 314/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1349 - val_loss: 1.5193
# Epoch 315/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2423 - val_loss: 1.1066
# Epoch 316/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2329 - val_loss: 1.2450
# Epoch 317/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1832 - val_loss: 1.2521
# Epoch 318/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0738 - val_loss: 1.0206
# Epoch 319/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1934 - val_loss: 1.3322
# Epoch 320/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1600 - val_loss: 1.3906
# Epoch 321/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1571 - val_loss: 1.1507
# Epoch 322/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1079 - val_loss: 1.0370
# Epoch 323/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1779 - val_loss: 1.2274
# Epoch 324/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2266 - val_loss: 1.3765
# Epoch 325/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0861 - val_loss: 1.1147
# Epoch 326/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0888 - val_loss: 1.2439
# Epoch 327/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2376 - val_loss: 1.1334
# Epoch 328/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1325 - val_loss: 1.1552
# Epoch 329/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1201 - val_loss: 1.0125
# Epoch 330/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0430 - val_loss: 1.2267
# Epoch 331/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2390 - val_loss: 1.3168
# Epoch 332/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1630 - val_loss: 1.0683
# Epoch 333/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1597 - val_loss: 1.5652
# Epoch 334/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1817 - val_loss: 1.1299
# Epoch 335/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0174 - val_loss: 1.1462
# Epoch 336/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1398 - val_loss: 1.3024
# Epoch 337/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0276 - val_loss: 1.1280
# Epoch 338/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1898 - val_loss: 1.2046
# Epoch 339/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0952 - val_loss: 1.3823
# Epoch 340/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9669 - val_loss: 1.2404
# Epoch 341/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1544 - val_loss: 1.0378
# Epoch 342/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1921 - val_loss: 1.1631
# Epoch 343/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1366 - val_loss: 1.1702
# Epoch 344/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0959 - val_loss: 1.6258
# Epoch 345/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2417 - val_loss: 1.3524
# Epoch 346/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0434 - val_loss: 1.1665
# Epoch 347/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2890 - val_loss: 0.9978
# Epoch 348/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9301 - val_loss: 1.0192
# Epoch 349/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0119 - val_loss: 1.3954
# Epoch 350/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1354 - val_loss: 1.2184
# Epoch 351/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1570 - val_loss: 1.0654
# Epoch 352/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2558 - val_loss: 1.1099
# Epoch 353/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0280 - val_loss: 1.0333
# Epoch 354/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1177 - val_loss: 1.3136
# Epoch 355/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1454 - val_loss: 1.2601
# Epoch 356/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3511 - val_loss: 1.2209
# Epoch 357/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0403 - val_loss: 0.8777
# Epoch 358/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2515 - val_loss: 0.9684
# Epoch 359/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0630 - val_loss: 1.1540
# Epoch 360/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0781 - val_loss: 1.2834
# Epoch 361/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1379 - val_loss: 1.0854
# Epoch 362/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3681 - val_loss: 1.0787
# Epoch 363/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1443 - val_loss: 0.9516
# Epoch 364/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1121 - val_loss: 1.3285
# Epoch 365/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1000 - val_loss: 1.2171
# Epoch 366/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1949 - val_loss: 0.8980
# Epoch 367/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0514 - val_loss: 1.3377
# Epoch 368/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0457 - val_loss: 0.9906
# Epoch 369/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0591 - val_loss: 1.4977
# Epoch 370/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0424 - val_loss: 0.9941
# Epoch 371/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0032 - val_loss: 1.3312
# Epoch 372/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2309 - val_loss: 1.1192
# Epoch 373/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0668 - val_loss: 1.1734
# Epoch 374/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0700 - val_loss: 1.1996
# Epoch 375/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0731 - val_loss: 1.1568
# Epoch 376/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2131 - val_loss: 1.0520
# Epoch 377/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0834 - val_loss: 1.1061
# Epoch 378/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1118 - val_loss: 1.1261
# Epoch 379/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0365 - val_loss: 1.1962
# Epoch 380/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2650 - val_loss: 1.4831
# Epoch 381/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2088 - val_loss: 1.1803
# Epoch 382/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1332 - val_loss: 0.8869
# Epoch 383/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3098 - val_loss: 0.9863
# Epoch 384/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0024 - val_loss: 0.9601
# Epoch 385/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1865 - val_loss: 1.0649
# Epoch 386/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1831 - val_loss: 1.1936
# Epoch 387/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0392 - val_loss: 1.2565
# Epoch 388/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.3000 - val_loss: 1.1470
# Epoch 389/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1116 - val_loss: 1.1520
# Epoch 390/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0861 - val_loss: 1.2780
# Epoch 391/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0566 - val_loss: 1.1031
# Epoch 392/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2247 - val_loss: 1.2518
# Epoch 393/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1960 - val_loss: 1.1993
# Epoch 394/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1969 - val_loss: 0.9215
# Epoch 395/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1482 - val_loss: 0.9869
# Epoch 396/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2321 - val_loss: 1.1835
# Epoch 397/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0233 - val_loss: 0.8612
# Epoch 398/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1194 - val_loss: 1.4077
# Epoch 399/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0363 - val_loss: 0.9764
# Epoch 400/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1204 - val_loss: 1.1959
# Epoch 401/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0528 - val_loss: 1.0513
# Epoch 402/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0886 - val_loss: 0.9280
# Epoch 403/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0789 - val_loss: 1.0834
# Epoch 404/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0516 - val_loss: 1.1697
# Epoch 405/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1195 - val_loss: 0.9642
# Epoch 406/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1011 - val_loss: 1.1471
# Epoch 407/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0865 - val_loss: 1.1627
# Epoch 408/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1764 - val_loss: 1.2304
# Epoch 409/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2638 - val_loss: 0.9236
# Epoch 410/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0904 - val_loss: 0.9935
# Epoch 411/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0376 - val_loss: 1.4810
# Epoch 412/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0610 - val_loss: 1.2911
# Epoch 413/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1266 - val_loss: 0.9867
# Epoch 414/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1076 - val_loss: 0.9738
# Epoch 415/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1565 - val_loss: 1.0107
# Epoch 416/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0440 - val_loss: 1.0196
# Epoch 417/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0274 - val_loss: 1.1728
# Epoch 418/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1424 - val_loss: 1.3179
# Epoch 419/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0755 - val_loss: 1.2342
# Epoch 420/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1130 - val_loss: 1.4695
# Epoch 421/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0192 - val_loss: 1.1069
# Epoch 422/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0711 - val_loss: 0.9987
# Epoch 423/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0656 - val_loss: 1.2169
# Epoch 424/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.0125 - val_loss: 1.0784
# Epoch 425/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1950 - val_loss: 1.2162
# Epoch 426/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0139 - val_loss: 1.1765
# Epoch 427/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 1.2310 - val_loss: 1.0921
# Epoch 428/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0484 - val_loss: 1.2317
# Epoch 429/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9421 - val_loss: 0.9663
# Epoch 430/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0835 - val_loss: 1.0434
# Epoch 431/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2360 - val_loss: 1.2727
# Epoch 432/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0130 - val_loss: 1.0031
# Epoch 433/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.1760 - val_loss: 0.9675
# Epoch 434/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3373 - val_loss: 1.0054
# Epoch 435/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0837 - val_loss: 1.2896
# Epoch 436/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3417 - val_loss: 1.2024
# Epoch 437/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2147 - val_loss: 1.0839
# Epoch 438/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0316 - val_loss: 0.9219
# Epoch 439/5000
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0142 - val_loss: 1.4223
# Epoch 440/5000
# ...
# Epoch 1799/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7658 - val_loss: 1.1908
# Epoch 1800/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7933 - val_loss: 1.1205
# Epoch 1801/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8635 - val_loss: 1.1940
# Epoch 1802/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7999 - val_loss: 1.5254
# Epoch 1803/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7549 - val_loss: 0.9553
# Epoch 1804/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8008 - val_loss: 1.1039
# Epoch 1805/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8019 - val_loss: 1.2273
# Epoch 1806/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7085 - val_loss: 0.9115
# Epoch 1807/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9246 - val_loss: 1.0678
# Epoch 1808/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7767 - val_loss: 1.1955
# Epoch 1809/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8633 - val_loss: 1.1237
# Epoch 1810/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8580 - val_loss: 1.0816
# Epoch 1811/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7392 - val_loss: 1.1134
# Epoch 1812/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8571 - val_loss: 1.0202
# Epoch 1813/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8935 - val_loss: 0.9732
# Epoch 1814/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9140 - val_loss: 1.1383
# Epoch 1815/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7587 - val_loss: 0.9809
# Epoch 1816/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7908 - val_loss: 1.0470
# Epoch 1817/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8193 - val_loss: 1.2391
# Epoch 1818/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7195 - val_loss: 1.0727
# Epoch 1819/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8528 - val_loss: 1.3815
# Epoch 1820/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8249 - val_loss: 1.0380
# Epoch 1821/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8769 - val_loss: 1.0047
# Epoch 1822/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8028 - val_loss: 1.1455
# Epoch 1823/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7830 - val_loss: 1.2597
# Epoch 1824/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8043 - val_loss: 1.2027
# Epoch 1825/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8652 - val_loss: 1.0213
# Epoch 1826/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8707 - val_loss: 1.0559
# Epoch 1827/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7403 - val_loss: 0.9990
# Epoch 1828/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9805 - val_loss: 1.0002
# Epoch 1829/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7987 - val_loss: 1.3398
# Epoch 1830/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8621 - val_loss: 0.8952
# Epoch 1831/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8282 - val_loss: 1.0041
# Epoch 1832/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7929 - val_loss: 1.0881
# Epoch 1833/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7648 - val_loss: 1.0244
# Epoch 1834/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7931 - val_loss: 1.0641
# Epoch 1835/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8865 - val_loss: 1.2843
# Epoch 1836/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8261 - val_loss: 1.2048
# Epoch 1837/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9192 - val_loss: 1.1157
# Epoch 1838/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7485 - val_loss: 1.0930
# Epoch 1839/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8321 - val_loss: 1.1219
# Epoch 1840/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9969 - val_loss: 1.0841
# Epoch 1841/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7758 - val_loss: 1.3382
# Epoch 1842/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8042 - val_loss: 0.8638
# Epoch 1843/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7779 - val_loss: 1.3570
# Epoch 1844/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8281 - val_loss: 1.1312
# Epoch 1845/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7573 - val_loss: 1.0823
# Epoch 1846/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7947 - val_loss: 0.9861
# Epoch 1847/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8333 - val_loss: 1.1156
# Epoch 1848/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8627 - val_loss: 1.1888
# Epoch 1849/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8225 - val_loss: 1.0264
# Epoch 1850/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8843 - val_loss: 1.0450
# Epoch 1851/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7933 - val_loss: 1.5244
# Epoch 1852/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.9153 - val_loss: 1.0970
# Epoch 1853/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8595 - val_loss: 0.9763
# Epoch 1854/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8209 - val_loss: 1.1218
# Epoch 1855/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7963 - val_loss: 1.0326
# Epoch 1856/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8112 - val_loss: 1.3349
# Epoch 1857/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8024 - val_loss: 1.2374
# Epoch 1858/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8524 - val_loss: 1.2084
# Epoch 1859/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7860 - val_loss: 0.9724
# Epoch 1860/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8326 - val_loss: 1.2856
# Epoch 1861/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8144 - val_loss: 1.3039
# Epoch 1862/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7850 - val_loss: 1.0166
# Epoch 1863/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.9002 - val_loss: 1.1036
# Epoch 1864/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9474 - val_loss: 1.0702
# Epoch 1865/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8120 - val_loss: 1.1605
# Epoch 1866/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8108 - val_loss: 1.0835
# Epoch 1867/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8262 - val_loss: 1.3477
# Epoch 1868/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8110 - val_loss: 1.0742
# Epoch 1869/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7354 - val_loss: 1.5007
# Epoch 1870/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7422 - val_loss: 1.4559
# Epoch 1871/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7778 - val_loss: 1.1185
# Epoch 1872/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8464 - val_loss: 1.1174
# Epoch 1873/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7729 - val_loss: 1.2519
# Epoch 1874/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8104 - val_loss: 1.0290
# Epoch 1875/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8980 - val_loss: 0.9525
# Epoch 1876/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8515 - val_loss: 1.0239
# Epoch 1877/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7683 - val_loss: 1.2006
# Epoch 1878/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9244 - val_loss: 1.3002
# Epoch 1879/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8081 - val_loss: 1.0706
# Epoch 1880/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8120 - val_loss: 0.9994
# Epoch 1881/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7668 - val_loss: 1.0232
# Epoch 1882/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8413 - val_loss: 1.3170
# Epoch 1883/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9036 - val_loss: 1.0414
# Epoch 1884/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8093 - val_loss: 1.0979
# Epoch 1885/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8364 - val_loss: 1.3033
# Epoch 1886/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9083 - val_loss: 1.3837
# Epoch 1887/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8488 - val_loss: 1.1198
# Epoch 1888/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8699 - val_loss: 1.3231
# Epoch 1889/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7199 - val_loss: 1.0191
# Epoch 1890/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8096 - val_loss: 1.1797
# Epoch 1891/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7627 - val_loss: 1.3552
# Epoch 1892/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7567 - val_loss: 1.1572
# Epoch 1893/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8152 - val_loss: 0.9761
# Epoch 1894/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7908 - val_loss: 0.9788
# Epoch 1895/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9160 - val_loss: 1.1474
# Epoch 1896/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8308 - val_loss: 1.0974
# Epoch 1897/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8269 - val_loss: 1.2392
# Epoch 1898/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8283 - val_loss: 1.0505
# Epoch 1899/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8098 - val_loss: 1.2375
# Epoch 1900/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8434 - val_loss: 0.8816
# Epoch 1901/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7979 - val_loss: 1.1011
# Epoch 1902/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8052 - val_loss: 1.0362
# Epoch 1903/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7792 - val_loss: 1.3688
# Epoch 1904/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7725 - val_loss: 0.8771
# Epoch 1905/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7645 - val_loss: 1.1062
# Epoch 1906/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8510 - val_loss: 1.1905
# Epoch 1907/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8858 - val_loss: 0.9995
# Epoch 1908/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8678 - val_loss: 1.1236
# Epoch 1909/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8162 - val_loss: 1.1645
# Epoch 1910/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8896 - val_loss: 1.2423
# Epoch 1911/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7397 - val_loss: 1.0414
# Epoch 1912/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8669 - val_loss: 0.9443
# Epoch 1913/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7914 - val_loss: 1.1067
# Epoch 1914/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7457 - val_loss: 1.2199
# Epoch 1915/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7431 - val_loss: 0.9258
# Epoch 1916/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8575 - val_loss: 1.1709
# Epoch 1917/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8019 - val_loss: 1.1296
# Epoch 1918/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8283 - val_loss: 1.3424
# Epoch 1919/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8505 - val_loss: 1.3122
# Epoch 1920/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8454 - val_loss: 1.2862
# Epoch 1921/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7416 - val_loss: 1.1446
# Epoch 1922/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8165 - val_loss: 0.8907
# Epoch 1923/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7709 - val_loss: 1.3822
# Epoch 1924/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7677 - val_loss: 1.1157
# Epoch 1925/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8798 - val_loss: 1.1802
# Epoch 1926/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8044 - val_loss: 1.2449
# Epoch 1927/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7733 - val_loss: 1.1952
# Epoch 1928/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8335 - val_loss: 1.0976
# Epoch 1929/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8451 - val_loss: 1.1556
# Epoch 1930/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7760 - val_loss: 1.2478
# Epoch 1931/5000
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7692 - val_loss: 0.9883
# Epoch 1932/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8160 - val_loss: 0.9005
# Epoch 1933/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8268 - val_loss: 1.1963
# Epoch 1934/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8100 - val_loss: 0.9677
# Epoch 1935/5000
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7871 - val_loss: 0.9306
# Epoch 1936/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.8357 - val_loss: 1.4547
# Epoch 1937/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8606 - val_loss: 1.0289
# Epoch 1938/5000
# 30/30 [==============================] - 0s 6ms/step - loss: 0.7992 - val_loss: 1.0214
# Epoch 1939/5000
# 30/30 [==============================] - 0s 9ms/step - loss: 0.9188 - val_loss: 1.3391
# Epoch 1940/5000
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7542 - val_loss: 1.3732
# Epoch 1941/5000
# 17/30 [================>.............] - ETA: 0s - loss: 0.7283Restoring model weights from the end of the best epoch: 941.
# 30/30 [==============================] - 0s 8ms/step - loss: 0.7759 - val_loss: 1.2290
# Epoch 1941: early stopping
# <ipython-input-16-09ca9af33de4>:9: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim((0, 10))
# Val loss: 0.6950934529304504
# Train loss: 0.9087944030761719
# Test loss: 1.0901113748550415
# dO18 RMSE: 1.1964555205812812
# EXPECTED:
#     d18O_mean  d18O_variance
# 1      24.662       0.527220
# 8      23.682       0.539420
# 9      27.714       0.461230
# 10     26.820       0.293950
# 11     26.686       0.267730
# 12     26.144       0.555280
# 13     26.134       0.194530
# 14     25.576       1.794680
# 15     25.196       0.410630
# 17     25.330       0.286467
# 18     25.882       0.233670
# 19     24.792       1.982470
# 20     26.220       0.532750
#
# PREDICTED:
#     d18O_mean  d18O_variance
# 0   25.207272       0.871368
# 1   25.423065       0.857394
# 2   25.208364       0.871532
# 3   25.183451       0.902019
# 4   25.194473       0.892344
# 5   25.171349       0.927025
# 6   25.104778       0.865634
# 7   25.131834       0.866584
# 8   24.863625       0.855292
# 9   25.215517       0.880657
# 10  25.399170       0.861367
# 11  24.914440       0.749990
# 12  24.984903       0.745139

# %%
model.save(get_model_save_location(
    f"{MODEL_NAME}.tf"), save_format='tf')
dump(data.feature_scaler, get_model_save_location(
    f"{MODEL_NAME}.pkl"))
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# ['/content/gdrive/MyDrive/amazon_rainforest_files/variational/model/truec_model.pkl']

# %%
vi_model = model.TFModel(
    get_model_save_location(f"{MODEL_NAME}.tf"),
    get_model_save_location(f"{MODEL_NAME}.pkl"))

required_geotiffs = [
    'VPD',
    'RH',
    'PET',
    'DEM',
    'PA',
    'Mean Annual Temperature',
    'Mean Annual Precipitation',
    'Iso_Oxi_Stack_mean_TERZER',
    'isoscape_fullmodel_d18O_prec_REGRESSION',
    "brisoscape_mean_ISORIX",
    "d13C_cel_mean",
    "d13C_cel_var",
    'ordinary_kriging_linear_d18O_predicted_mean',
    'ordinary_kriging_linear_d18O_predicted_variance',]

raster.generate_isoscapes_from_variational_model(
    model=vi_model, required_geotiffs=required_geotiffs, output_geotiff=MODEL_NAME, res_x=1000, res_y=1000)
# Out:
# Driver: GTiff/GeoTIFF
# Size is 941 x 937 x 12
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.04166666666665718, -0.04166666666667143)
# Driver: GTiff/GeoTIFF
# Size is 941 x 937 x 12
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.04166666666665718, -0.04166666666667143)
# Driver: GTiff/GeoTIFF
# Size is 942 x 936 x 1
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 5.25)
# Pixel Size = (0.041666666666666664, -0.041666666666666664)
# Driver: GTiff/GeoTIFF
# Size is 5418 x 4683 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-73.991666667, 5.275)
# Pixel Size = (0.008333333333333335, -0.008333333333333333)
# Driver: GTiff/GeoTIFF
# Size is 5418 x 4683 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-73.991666667, 5.275)
# Pixel Size = (0.008333333333333335, -0.008333333333333333)
# Driver: GTiff/GeoTIFF
# Size is 941 x 937 x 12
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.04166666666665718, -0.04166666666667143)
# Driver: GTiff/GeoTIFF
# Size is 235 x 234 x 1
# Projection is
# Origin = (-74.0, 5.333333333999995)
# Pixel Size = (0.16666666666808508, -0.16666666666808505)
# Driver: GTiff/GeoTIFF
# Size is 940 x 936 x 1
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-73.975139313, 5.266527396)
# Pixel Size = (0.0416666665, -0.041666666500000005)
# Driver: GTiff/GeoTIFF
# Size is 235 x 234 x 1
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 5.333333334)
# Pixel Size = (0.1666666666680851, -0.16666666666666666)
# Driver: GTiff/GeoTIFF
# Size is 541 x 467 x 1
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-73.922043, 5.233124)
# Pixel Size = (0.08333, -0.08333)
# Driver: GTiff/GeoTIFF
# Size is 235 x 218 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 4.500000000659528)
# Pixel Size = (0.166666666667993, -0.16666666666799657)
# Driver: GTiff/GeoTIFF
# Size is 235 x 218 x 2
# Projection is GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4674"]]
# Origin = (-74.0, 4.500000000659528)
# Pixel Size = (0.166666666667993, -0.16666666666799657)
# Driver: GTiff/GeoTIFF
# Size is 235 x 234 x 1
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0, 5.333333333999995)
# Pixel Size = (0.16666666666808508, -0.16666666666808505)
# Driver: GTiff/GeoTIFF
# Size is 235 x 234 x 1
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0, 5.333333333999995)
# Pixel Size = (0.16666666666808508, -0.16666666666808505)
# 100%|██████████| 1001/1001 [02:46<00:00,  6.02it/s]
