# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf-isoscapes/blob/npr-working/brazil-ood-evals-for-paper-rmse-124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Isoscape Evals
#
# Notebook Purpose: Eval isoscape generation methods for our paper
#
# Isoscape Task: Find the mean/variance of O18 ratios (as well as N15 and C13 in the future) at a particular lat/lon across Brazil.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Fetch Dependencies

# %%
# !pip install rasterio fiona pykrige
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting fiona
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.4 MB/s eta 0:00:00
# Collecting pykrige
#   Downloading PyKrige-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.4.26)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.2.1)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.3)
# Requirement already satisfied: scipy<2,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from pykrige) (1.15.3)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 20.2 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 20.0 MB/s eta 0:00:00
# Downloading PyKrige-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (979 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.6/979.6 kB 17.0 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio, pykrige, fiona
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 fiona-1.10.1 pykrige-1.7.2 rasterio-1.4.3

# %% [markdown]
# ### If Doing Monte-Carlo: PyMC3 is not packaged properly. Install that.

# %%
# !pip install mkl-service versioneer
# Out:
# Collecting mkl-service
#   Downloading mkl_service-2.4.2-0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Collecting versioneer
#   Downloading versioneer-0.29-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from mkl-service) (2025.0.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->mkl-service) (2025.1.1)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->mkl-service) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->mkl-service) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.1.1 in /usr/local/lib/python3.11/dist-packages (from intel-openmp>=2024->mkl->mkl-service) (2025.1.1)
# Requirement already satisfied: umf==0.10.* in /usr/local/lib/python3.11/dist-packages (from intel-cmplr-lib-ur==2025.1.1->intel-openmp>=2024->mkl->mkl-service) (0.10.0)
# Downloading mkl_service-2.4.2-0-cp311-cp311-manylinux_2_28_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.5 MB/s eta 0:00:00
# Downloading versioneer-0.29-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: versioneer, mkl-service
# Successfully installed mkl-service-2.4.2 versioneer-0.29

# %%
# !git clone https://github.com/pymc-devs/pymc3
# !cd pymc3 && pip install -r requirements.txt

# %%
# !cd pymc3 && python setup.py install

# %%
# !rm -rf pymc3

# %% [markdown]
# ## Import libraries required

# %%
import importlib
from datetime import datetime
import sys
import os

# %%
# !if [ ! -d "/content/ddf_common_stub" ] ; then git clone -b test https://github.com/tnc-br/ddf_common_stub.git; fi
sys.path.append("/content/ddf_common_stub/")
import ddfimport
ddfimport.ddf_import_common(email="tripiace@yahoo.com")
# Out:
# executing checkout_branch ...
# Branch rmse already checked out.
# Remember to reload your imports with `importlib.reload(module)`.
# b''
# main branch checked out as readonly. You may now use ddf_common imports

# %%
import train_variational_inference_model as tvim
import raster
import eeddf
import model
import dataset
import fiona
import rasterio.mask
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount(raster.GDRIVE_BASE)
import importlib

importlib.reload(model)

# Leave test_environment=True. Experiments must be done in test.
eeddf.initialize_ddf(test_environment=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Patch https://github.com/tnc-br/ddf_common/issues/72 here
import evaluation
importlib.reload(evaluation)
importlib.reload(model)
importlib.reload(tvim)
importlib.reload(train_variational_inference_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7beef8ed1666> in <cell line: 0>()
#       2 import evaluation
#       3 importlib.reload(evaluation)
# ----> 4 importlib.reload(model)
#       5 importlib.reload(tvim)
#       6 importlib.reload(train_variational_inference_model)
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Data configuration

# %%
# REQUIREMENTS:

# 1) Column names must match features_to_standardize, features_to_passthrough
# 2) Label columns in particular must match var_label and mean_label.
#
# If you used the data ingestion notebook (ingestion.ipynb) then this
# should be set up for you already.

# TRAINING FILE PARAMS
DATABASE_DIR = raster.GDRIVE_BASE + raster.SAMPLE_DATA_BASE
TRAINING_SET_FILE = 'canonical/12_16_filtered_train_random_grouped_no_nans.csv' #@param
VALIDATION_SET_FILE = 'canonical/12_16_filtered_validation_random_grouped.csv' #@param
TEST_SET_FILE = 'canonical/12_16_filtered_test_random_grouped.csv' #@param

# EVAL FILE PARAMS
EVAL_DATASET = 'canonical/12_16_filtered_test_random_grouped_no_nans.csv' #@param
#ORIGINAL_DATASET = 'canonical/2023_07_27_Results_google_utf8_latlonadded.csv' #@param
ORIGINAL_DATASET = 'canonical/12_16_ungrouped.csv' #@param


fileset = {
    'TRAIN' : os.path.join(DATABASE_DIR, TRAINING_SET_FILE),
    'TEST' : os.path.join(DATABASE_DIR, VALIDATION_SET_FILE),
    'VALIDATION' : os.path.join(DATABASE_DIR, TEST_SET_FILE),
    'EVAL' : os.path.join(DATABASE_DIR, EVAL_DATASET),
    'ORIGINAL' : os.path.join(DATABASE_DIR, ORIGINAL_DATASET)
}

def prepare_dataset(params: tvim.VIModelTrainingParams, files: dict) -> dataset.ScaledPartitions:
  # Prepared columns not in the original input-- these are engineered features
  # that we believe include strong signals, stored as geotiffs
  potentially_extra_columns = [
      "brisoscape_mean_ISORIX",
      "d13C_cel_mean",
      "d13C_cel_var",
      "ordinary_kriging_linear_d18O_predicted_mean",
      "ordinary_kriging_linear_d18O_predicted_variance",
  ]

  #Load the geotiff it the params request it.
  extra_columns_from_geotiffs = {}
  for feature in params.features_to_passthrough + params.features_to_standardize:
      if feature in potentially_extra_columns:
          extra_columns_from_geotiffs[feature] = raster.column_name_to_geotiff_fn[feature]()

  return dataset.load_and_scale(
      files,
      params.mean_label,
      params.var_label,
      params.features_to_passthrough,
      [],
      params.features_to_standardize,
      extra_columns_from_geotiffs)

with fiona.open('zip:///content/gdrive/MyDrive/amazon_rainforest_files/shapefiles/bra_adm_ibge_2020_shp.zip') as shp:
  BRAZIL_SHP_MASK = [feature["geometry"] for feature in shp]

with fiona.open('zip:///content/gdrive/MyDrive/amazon_rainforest_files/shapefiles/Amazon Biome.zip/data/commondata/data0') as shp:
  AMAZON_SHP_MASK = [feature["geometry"] for feature in shp]

# Load these lazily later from the first generated isoscapes

def display_brazil(band_index: int):
  with rasterio.open(ISOSCAPE_SAVE_LOCATION) as src:
    raster_data = src.read(band_index+1)  # Read the first band
    out_image, out_transform = rasterio.mask.mask(src, BRAZIL_SHP_MASK, crop=False)
    out_meta = src.meta
    brazil_np_mask = np.logical_not(out_image.astype(bool))

  geotiff = raster.load_raster(ISOSCAPE_SAVE_LOCATION, use_only_band_index=band_index)
  fig = plt.figure( figsize=(8,8) )
  extent = raster.get_extent(geotiff.gdal_dataset).to_matplotlib()
  ax = fig.add_subplot()
  to_show = np.ma.MaskedArray(geotiff.yearly_masked_image.data, brazil_np_mask[0])
  im = fig.axes[0].imshow(to_show, interpolation='none', aspect='auto', extent = extent)
  plt.colorbar(im)

def display_amazon(band_index: int):
  with rasterio.open(ISOSCAPE_SAVE_LOCATION) as src:
    raster_data = src.read(band_index+1)  # Read the first band
    out_image, out_transform = rasterio.mask.mask(src, AMAZON_SHP_MASK, crop=False)
    out_meta = src.meta
    amazon_np_mask = np.logical_not(out_image.astype(bool))

  geotiff = raster.load_raster(ISOSCAPE_SAVE_LOCATION, use_only_band_index=band_index)
  fig = plt.figure( figsize=(8,8) )
  extent = raster.get_extent(geotiff.gdal_dataset).to_matplotlib()
  ax = fig.add_subplot()
  to_show = np.ma.MaskedArray(geotiff.yearly_masked_image.data, amazon_np_mask[0])
  im = fig.axes[0].imshow(to_show, interpolation='none', aspect='auto', extent = extent)
  plt.colorbar(im)

# %% [markdown]
# # Non-VI Models

# %% [markdown]
# ## Ordinary Kriging
#
# Based on https://geostat-framework.readthedocs.io/projects/pykrige/en/stable/examples/00_ordinary.html

# %%
import pykrige.kriging_tools as kt
from pykrige.ok import OrdinaryKriging

# %%
params = tvim.VIModelTrainingParams(
    training_id = "test-okrige-2025-04-18-2", #@param
    num_epochs = -1,
    num_layers = -1,
    num_nodes_per_layer = -1,
    training_batch_size = -1,
    learning_rate = -1,
    mean_label = "d18O_cel_mean", #@param
    var_label = "d18O_cel_variance", #@param
    early_stopping_patience = -1,
    min_steps=-1,
    double_sided_kl = False,
    kl_num_samples_from_pred_dist = 1,
    dropout_rate = -1,
    activation_func = "",
    features_to_standardize = ['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA', 'Mean Annual Temperature', 'Mean Annual Precipitation', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION', 'brisoscape_mean_ISORIX', 'd13C_cel_mean', 'd13C_cel_var', 'ordinary_kriging_linear_d18O_predicted_mean', 'ordinary_kriging_linear_d18O_predicted_variance', 'd13C_foliar',	'd15N_foliar', 'd15N_soil'], #@param
    features_to_passthrough = [], #@param
    resolution_x = 1024, #@param
    resolution_y = 1024, #@param
    tags = ["author:npr", "ordinary_kriging", "all_standardized", "gaussian_variogram", "rev5"], #@param
    n_cv_folds=None,
)
eval_params = tvim.VIModelEvalParams(
    samples_per_location = 5, #@param
    precision_target = 0.95, #@param
    recall_target = None, #@param
    start_max_fraud_radius= 6, #@param
    end_max_fraud_radius = 3000, #@param
    radius_pace = 100, #@param
    trusted_buffer_radius = 5, #@param
    elements_to_eval = ['d18O_cel'], #@param
)


MODEL_SAVE_LOCATION = os.path.join(raster.GDRIVE_BASE, raster.MODEL_BASE, params.training_id + ".keras")
ISOSCAPE_SAVE_LOCATION = raster.get_raster_path(params.training_id+".tiff")

# %%
data = prepare_dataset(params, fileset)

# %%
data.train.X['d15N_soil']
# Out:
# 0     -0.522920
# 1      1.987839
# 2     -0.522920
# 3      0.517171
# 4      0.852685
#          ...
# 192   -0.522920
# 193   -0.138477
# 194   -1.370091
# 195    0.870859
# 196   -0.522920
# Name: d15N_soil, Length: 197, dtype: float64

# %%
# Drop rows with NaN values from data.train.X and filter data.train.Y
data.train.X.dropna(inplace=True)
data.train.Y = data.train.Y.loc[data.train.X.index]

# %%
import pandas as pd
import numpy as np
import raster
import generate_isoscape
from sklearn.metrics import mean_squared_error

raw_train = pd.read_csv(fileset['TRAIN'])

# %%
def run_ordinary_kriging(**kwargs):
  # Not enough data to properly fit a Gaussian variogram
  ok = OrdinaryKriging(data.train.X['lat'], data.train.X['long'], data.train.Y['d18O_cel_mean'], **kwargs)

  min_long = min(data.train.X['long'])
  max_long = max(data.train.X['long'])
  min_lat = min(data.train.X['lat'])
  max_lat = max(data.train.X['lat'])

  # Predict the isotope values on the range of lattitude and longitude values
  # within the bounds of our VPD geotiff (should be Brazil-shaped), then save
  # for qualitative eval / display
  isoscape_long_values =  np.linspace(min_long, max_long, params.resolution_x)
  isoscape_lat_values = np.linspace(min_lat, max_lat, params.resolution_y)

  means, variances  = ok.execute("grid", isoscape_long_values,
                                  isoscape_lat_values)
  ok.print_statistics()

  arbitrary_geotiff = raster.vapor_pressure_deficit_geotiff()
  base_bounds = raster.get_extent(arbitrary_geotiff.gdal_dataset)
  final_bounds = raster.create_bounds_from_res(params.resolution_x, params.resolution_y, base_bounds)

  all_predictions = np.ma.masked_array([means, variances], mask=[np.isnan(means), np.isnan(variances)]) # raster, lat, lon
  all_predictions = np.transpose(all_predictions, axes=[1, 2, 0]) # lat, lon, raster

  generate_isoscape.save_numpy_to_geotiff(final_bounds, all_predictions, ISOSCAPE_SAVE_LOCATION)

  # Quantitative Eval Metrics
  test_pred_means, test_pred_vars  = ok.execute("points", data.test.X['long'],
                                  data.test.X['lat'])
  test_ground_means = data.test.Y[params.mean_label]
  test_ground_vars = data.test.Y[params.var_label]
  print(f'Means RMSE: {np.sqrt(mean_squared_error(test_ground_means, test_pred_means))}')
  print(f'Variances RMSE: {np.sqrt(mean_squared_error(test_ground_vars, test_pred_vars))}')

# %%
# Not enough data for a gaussian variogram (we only use the 'train' split)
run_ordinary_kriging(variogram_model='linear')
# Out:
# Q1 = None
# Q2 = None
# cR = None
# Means RMSE: 1.3465345306384018
# Variances RMSE: 0.7519736955498336

# %%
display_brazil(0) # Means

# %%
display_amazon(0) # Means

# %%
EVAL_ONLY = True
res = tvim.train_variational_inference_model(params, eval_params, fileset, ISOSCAPE_SAVE_LOCATION, MODEL_SAVE_LOCATION, eval_only=EVAL_ONLY)
# Out:
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)

# %%
params.tags
# Out:
# ['author:npr',
#  'ordinary_kriging',
#  'all_standardized',
#  'gaussian_variogram',
#  'rev5']

# %% [markdown]
# ## Universal Kriging
#
# Based on https://geostat-framework.readthedocs.io/projects/pykrige/en/stable/examples/01_universal.html

# %%
params = tvim.VIModelTrainingParams(
    training_id = "test-ukrige-2025-04-18-1", #@param
    num_epochs = -1,
    num_layers = -1,
    num_nodes_per_layer = -1,
    training_batch_size = -1,
    learning_rate = -1,
    mean_label = "d18O_cel_mean", #@param
    var_label = "d18O_cel_variance", #@param
    early_stopping_patience = -1,
    min_steps=-1,
    double_sided_kl = False,
    kl_num_samples_from_pred_dist = 1,
    dropout_rate = -1,
    activation_func = "",
    features_to_standardize = ['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA', 'Mean Annual Temperature', 'Mean Annual Precipitation', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION', 'brisoscape_mean_ISORIX', 'd13C_cel_mean', 'd13C_cel_var', 'ordinary_kriging_linear_d18O_predicted_mean', 'ordinary_kriging_linear_d18O_predicted_variance'], #@param
    features_to_passthrough = [], #@param
    resolution_x = 1024, #@param
    resolution_y = 1024, #@param
    tags = ["author:npr", "universal_kriging", "all_standardized", "linear_variogram", "rev3"], #@param
    n_cv_folds=None,
)
eval_params = tvim.VIModelEvalParams(
    samples_per_location = 5, #@param
    precision_target = 0.95, #@param
    recall_target = None, #@param
    start_max_fraud_radius= 6, #@param
    end_max_fraud_radius = 3000, #@param
    radius_pace = 100, #@param
    trusted_buffer_radius = 5, #@param
    elements_to_eval = ['d18O_cel'], #@param
)


MODEL_SAVE_LOCATION = os.path.join(raster.GDRIVE_BASE, raster.MODEL_BASE, params.training_id + ".keras")
ISOSCAPE_SAVE_LOCATION = raster.get_raster_path(params.training_id+".tiff")

# %%
data = prepare_dataset(params, fileset)

# %%
import pandas as pd
import numpy as np
import raster
import pykrige.kriging_tools as kt
from pykrige.uk import UniversalKriging
from sklearn.metrics import mean_squared_error
raw_train = pd.read_csv(fileset['TRAIN'])

# %%
def run_universal_kriging(**kwargs):
  uk = UniversalKriging(data.train.X['lat'], data.train.X['long'], data.train.Y['d18O_cel_mean'], **kwargs)
  min_long = min(data.train.X['long'])
  max_long = max(data.train.X['long'])
  min_lat = min(data.train.X['lat'])
  max_lat = max(data.train.X['lat'])

  # Predict the isotope values on the range of lattitude and longitude values
  # within the bounds of our VPD geotiff (should be Brazil-shaped), then save
  # for qualitative eval / display
  isoscape_long_values =  np.linspace(min_long, max_long, params.resolution_x)
  isoscape_lat_values = np.linspace(min_lat, max_lat, params.resolution_y)
  means, variances  = uk.execute("grid", isoscape_long_values,
                                  isoscape_lat_values)
  uk.print_statistics()

  arbitrary_geotiff = raster.vapor_pressure_deficit_geotiff()
  base_bounds = raster.get_extent(arbitrary_geotiff.gdal_dataset)
  final_bounds = raster.create_bounds_from_res(params.resolution_x, params.resolution_y, base_bounds)

  all_predictions = np.ma.masked_array([means, variances], mask=[np.isnan(means), np.isnan(variances)]) # raster, lat, lon
  all_predictions = np.transpose(all_predictions, axes=[1, 2, 0]) # lat, lon, raster

  generate_isoscape.save_numpy_to_geotiff(final_bounds, all_predictions, ISOSCAPE_SAVE_LOCATION)

  # Quantitative Eval Metrics
  test_pred_means, test_pred_vars  = uk.execute("points", data.test.X['long'],
                                  data.test.X['lat'])
  test_ground_means = data.test.Y[params.mean_label]
  test_ground_vars = data.test.Y[params.var_label]
  print(f'Means RMSE: {np.sqrt(mean_squared_error(test_ground_means, test_pred_means))}')
  print(f'Variances RMSE: {np.sqrt(mean_squared_error(test_ground_vars, test_pred_vars))}')

# %%
run_universal_kriging(variogram_model='gaussian', drift_terms=['regional_linear'])
# Out:
# Q1 = 0.2382429935229234
# Q2 = 1.2573228101735001
# cR = 1.516487672064444
# Means RMSE: 1.4910069942128807
# Variances RMSE: 0.7214404419209571

# %%
display_brazil(0)

# %%
EVAL_ONLY = True
res = tvim.train_variational_inference_model(params, eval_params, fileset, ISOSCAPE_SAVE_LOCATION, MODEL_SAVE_LOCATION, eval_only=EVAL_ONLY)
# Out:
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)

# %% [markdown]
# ## Regression Kriging
#
# Based on https://geostat-framework.readthedocs.io/projects/pykrige/en/stable/examples/07_regression_kriging2d.html

# %%
params = tvim.VIModelTrainingParams(
    training_id = "test-rkrige-2025-01-31-2", #@param
    num_epochs = -1,
    num_layers = -1,
    num_nodes_per_layer = -1,
    training_batch_size = -1,
    learning_rate = -1,
    mean_label = "d18O_cel_mean", #@param
    var_label = "d18O_cel_variance", #@param
    early_stopping_patience = -1,
    min_steps=-1,
    double_sided_kl = False,
    kl_num_samples_from_pred_dist = 1,
    dropout_rate = -1,
    activation_func = "",
    features_to_standardize = ['VPD', 'RH', 'PET', 'DEM', 'PA', 'Mean Annual Temperature', 'Mean Annual Precipitation', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION', 'brisoscape_mean_ISORIX', 'd13C_cel_mean', 'd13C_cel_var', 'ordinary_kriging_linear_d18O_predicted_mean', 'ordinary_kriging_linear_d18O_predicted_variance'], #@param
    features_to_passthrough = ['lat', 'long'], #@param
    resolution_x = 1024, #@param
    resolution_y = 1024, #@param
    tags = ["author:npr", "regression_kriging", "all_standardized", "rev2", "krige_type:regression", "variogram:gaussian", "n_estimators:100", "max_depth:20", "regression_strategy:gradientboosting"], #@param
    n_cv_folds = None
)
eval_params = tvim.VIModelEvalParams(
    samples_per_location = 5, #@param
    precision_target = 0.95, #@param
    recall_target = None, #@param
    start_max_fraud_radius= 6, #@param
    end_max_fraud_radius = 3000, #@param
    radius_pace = 100, #@param
    trusted_buffer_radius = 5, #@param
    elements_to_eval = ['d18O_cel'], #@param
)


MODEL_SAVE_LOCATION = os.path.join(raster.GDRIVE_BASE, raster.MODEL_BASE, params.training_id + ".keras")
ISOSCAPE_SAVE_LOCATION = raster.get_raster_path(params.training_id+".tiff")

# %%
import pandas as pd
import numpy as np
import raster
from numpy.typing import NDArray
from typing import Tuple, List

from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import generate_isoscape
import model

from pykrige.rk import RegressionKriging


def run_regression_kriging(regression_model, regression_kwargs, krige_kwargs):
  data = prepare_dataset(params, fileset)
  raw_train = pd.read_csv(fileset['TRAIN']).dropna()
  raw_val = pd.read_csv(fileset['VALIDATION']).dropna()

  svr_model = SVR(C=0.1, gamma="auto")
  rf_model = RandomForestRegressor(n_estimators=1000)
  lr_model = LinearRegression(copy_X=True, fit_intercept=True)
  gb_model = GradientBoostingRegressor(n_estimators=100, max_depth=20)

  models = [svr_model, rf_model, lr_model]

  train_features = params.features_to_standardize + params.features_to_passthrough
  train_features_nolatlon = list(train_features)
  train_features_nolatlon.remove('lat')
  train_features_nolatlon.remove('long')

  p_train = pd.concat((data.train.X[train_features_nolatlon], data.val.X[train_features_nolatlon],), join='inner')
  x_train = np.concatenate((np.array(tuple(zip(raw_train['lat'], raw_train['long']))), np.array(tuple(zip(raw_val['lat'], raw_val['long'])))))
  target_train = pd.concat((raw_train[params.mean_label], raw_val[params.mean_label],), join='inner')


  rk = RegressionKriging(regression_model=regression_model(**regression_kwargs), **krige_kwargs)
  # Why do I call .to_numpy() here?
  # to_numpy() removes feature names, which ColumnTransformer.transform() strips
  # in predict_on_batch(). If trained with feature names but inference is run
  # without, a long list of warnings will be printed and isoscape generation will
  # be slower.
  rk.fit(p_train.to_numpy(), x_train, target_train)


  class DDFRegressionKrigingModel(model.Model):
    # #@override
    def __init__(self, rk: RegressionKriging, training_cols: List[str]):
      self.rk = rk
      self.training_cols = training_cols

    # #@override
    def predict_on_batch(self, X: pd.DataFrame) -> NDArray[np.float32]:
      #TODO(ruru): Maybe our isoscape generator should standardize the features in features_to_standardize here as well
      #TODO: The scaling step appears to add some time. This might be a good target for future performance efforts.
      XT = data.feature_scaler.transform(X)
      latindex = X.columns.get_loc('lat')
      longindex = X.columns.get_loc('long')
      x = X[['lat', 'long']].to_numpy()
      p = np.delete(XT, [latindex, longindex],axis=1)
      means = self.rk.predict(p, x)
      return np.array([means, np.zeros(means.shape)]).T

    # #@override
    def training_column_names(self) -> List[str]:
      return ['lat', 'long'] + self.training_cols


  rkm = DDFRegressionKrigingModel(rk=rk, training_cols=train_features_nolatlon)



  # Quantitative Eval Metrics
  test_preds = rkm.predict_on_batch(data.test.X)
  test_pred_means = test_preds[:,0]
  test_ground_means = data.test.Y[params.mean_label]
  print(f'Means RMSE: {np.sqrt(mean_squared_error(test_ground_means, test_pred_means))}')


  generate_isoscape.generate_isoscapes_from_variational_model(rkm, 1024, 1024, ISOSCAPE_SAVE_LOCATION)

# %%
run_regression_kriging(GradientBoostingRegressor, {'n_estimators':100, 'max_depth':20}, {'method': 'universal', 'variogram_model':'gaussian', 'drift_terms':['regional_linear']})
# Out:
# Finished learning regression model
# Finished kriging residuals
# n_closest_points will be ignored for UniversalKriging
# Means RMSE: 2.252972516201693
#   0%|          | 5/1024 [00:00<00:29, 34.21it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   1%|          | 9/1024 [00:00<00:45, 22.48it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   1%|          | 12/1024 [00:00<00:54, 18.67it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   1%|▏         | 14/1024 [00:00<00:55, 18.12it/s]
# n_closest_points will be ignored for UniversalKriging
#   2%|▏         | 16/1024 [00:00<00:57, 17.42it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   2%|▏         | 18/1024 [00:01<01:06, 15.02it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   2%|▏         | 20/1024 [00:01<01:07, 14.83it/s]
# n_closest_points will be ignored for UniversalKriging
#   2%|▏         | 22/1024 [00:01<01:09, 14.48it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   2%|▏         | 24/1024 [00:01<01:10, 14.12it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   3%|▎         | 26/1024 [00:01<01:12, 13.79it/s]
# n_closest_points will be ignored for UniversalKriging
#   3%|▎         | 28/1024 [00:01<01:14, 13.37it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   3%|▎         | 30/1024 [00:01<01:16, 13.06it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   3%|▎         | 32/1024 [00:02<01:19, 12.44it/s]
# n_closest_points will be ignored for UniversalKriging
#   3%|▎         | 34/1024 [00:02<01:20, 12.32it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   4%|▎         | 36/1024 [00:02<01:20, 12.22it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   4%|▎         | 38/1024 [00:02<01:22, 12.01it/s]
# n_closest_points will be ignored for UniversalKriging
#   4%|▍         | 40/1024 [00:02<01:22, 12.00it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   4%|▍         | 42/1024 [00:02<01:22, 11.85it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   4%|▍         | 44/1024 [00:03<01:25, 11.48it/s]
# n_closest_points will be ignored for UniversalKriging
#   4%|▍         | 46/1024 [00:03<01:23, 11.75it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   5%|▍         | 48/1024 [00:03<01:24, 11.57it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   5%|▌         | 52/1024 [00:03<01:25, 11.36it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   5%|▌         | 54/1024 [00:04<01:26, 11.21it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   6%|▌         | 58/1024 [00:04<01:27, 11.06it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   6%|▌         | 60/1024 [00:04<01:26, 11.08it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   6%|▌         | 62/1024 [00:04<01:26, 11.07it/s]
# n_closest_points will be ignored for UniversalKriging
#   6%|▋         | 64/1024 [00:04<01:26, 11.12it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   6%|▋         | 66/1024 [00:05<01:26, 11.08it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   7%|▋         | 70/1024 [00:05<01:26, 10.97it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   7%|▋         | 72/1024 [00:05<01:26, 10.99it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   7%|▋         | 74/1024 [00:05<01:24, 11.22it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   7%|▋         | 76/1024 [00:06<01:24, 11.17it/s]
# n_closest_points will be ignored for UniversalKriging
#   8%|▊         | 78/1024 [00:06<01:27, 10.79it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   8%|▊         | 80/1024 [00:06<01:26, 10.97it/s]
# n_closest_points will be ignored for UniversalKriging
#   8%|▊         | 82/1024 [00:06<01:25, 10.99it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   8%|▊         | 84/1024 [00:06<01:25, 11.03it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   8%|▊         | 86/1024 [00:06<01:24, 11.09it/s]
# n_closest_points will be ignored for UniversalKriging
#   9%|▊         | 88/1024 [00:07<01:22, 11.28it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   9%|▉         | 90/1024 [00:07<01:23, 11.15it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   9%|▉         | 92/1024 [00:07<01:22, 11.28it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   9%|▉         | 94/1024 [00:07<01:26, 10.76it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#   9%|▉         | 96/1024 [00:07<01:26, 10.79it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  10%|▉         | 98/1024 [00:08<01:26, 10.76it/s]
# n_closest_points will be ignored for UniversalKriging
#  10%|▉         | 100/1024 [00:08<01:25, 10.82it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  10%|▉         | 102/1024 [00:08<01:30, 10.18it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  10%|█         | 104/1024 [00:08<01:30, 10.22it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  10%|█         | 106/1024 [00:08<01:28, 10.37it/s]
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 108/1024 [00:09<01:29, 10.24it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 110/1024 [00:09<01:31,  9.99it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 112/1024 [00:09<01:37,  9.39it/s]
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 113/1024 [00:09<01:40,  9.09it/s]
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 114/1024 [00:09<01:40,  9.09it/s]
# n_closest_points will be ignored for UniversalKriging
#  11%|█         | 115/1024 [00:09<01:50,  8.23it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  11%|█▏        | 116/1024 [00:10<02:06,  7.20it/s]
# n_closest_points will be ignored for UniversalKriging
#  11%|█▏        | 117/1024 [00:10<02:15,  6.71it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 119/1024 [00:10<03:11,  4.72it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 120/1024 [00:11<03:32,  4.25it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 121/1024 [00:11<03:49,  3.93it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 122/1024 [00:11<03:56,  3.81it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 123/1024 [00:11<03:35,  4.19it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 125/1024 [00:12<03:12,  4.67it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  12%|█▏        | 127/1024 [00:12<03:40,  4.08it/s]
# n_closest_points will be ignored for UniversalKriging
#  12%|█▎        | 128/1024 [00:13<03:31,  4.24it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  13%|█▎        | 130/1024 [00:13<03:44,  3.97it/s]
# n_closest_points will be ignored for UniversalKriging
#  13%|█▎        | 131/1024 [00:13<03:44,  3.98it/s]
# n_closest_points will be ignored for UniversalKriging
#  13%|█▎        |
/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  90%|█████████ | 924/1024 [02:55<00:12,  8.31it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  90%|█████████ | 926/1024 [02:55<00:11,  8.48it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  91%|█████████ | 928/1024 [02:56<00:11,  8.49it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  91%|█████████ | 930/1024 [02:56<00:11,  8.51it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  91%|█████████ | 932/1024 [02:56<00:10,  8.36it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  91%|█████████ | 934/1024 [02:56<00:11,  7.84it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  91%|█████████▏| 936/1024 [02:57<00:10,  8.01it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 938/1024 [02:57<00:10,  8.45it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 940/1024 [02:57<00:09,  8.76it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 942/1024 [02:57<00:09,  8.38it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 944/1024 [02:58<00:10,  7.55it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 945/1024 [02:58<00:11,  7.16it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  92%|█████████▏| 947/1024 [02:58<00:13,  5.83it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 949/1024 [02:59<00:15,  4.76it/s]
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 950/1024 [02:59<00:16,  4.49it/s]
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 951/1024 [02:59<00:14,  4.94it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 953/1024 [02:59<00:15,  4.52it/s]
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 954/1024 [03:00<00:15,  4.48it/s]
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 955/1024 [03:00<00:14,  4.87it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  93%|█████████▎| 957/1024 [03:00<00:14,  4.50it/s]
# n_closest_points will be ignored for UniversalKriging
#  94%|█████████▎| 958/1024 [03:01<00:15,  4.20it/s]
# n_closest_points will be ignored for UniversalKriging
#  94%|█████████▎| 959/1024 [03:01<00:13,  4.76it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  94%|█████████▍| 961/1024 [03:01<00:12,  5.01it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  94%|█████████▍| 963/1024 [03:02<00:12,  4.89it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  94%|█████████▍| 966/1024 [03:02<00:09,  6.41it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▍| 968/1024 [03:02<00:07,  7.04it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▍| 970/1024 [03:02<00:07,  7.20it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▍| 972/1024 [03:03<00:07,  7.17it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▌| 974/1024 [03:03<00:06,  7.83it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▌| 976/1024 [03:03<00:06,  7.29it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  95%|█████████▌| 977/1024 [03:03<00:06,  7.18it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  96%|█████████▌| 979/1024 [03:04<00:09,  4.98it/s]
# n_closest_points will be ignored for UniversalKriging
#  96%|█████████▌| 981/1024 [03:04<00:07,  5.64it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  96%|█████████▌| 983/1024 [03:05<00:06,  6.31it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  96%|█████████▋| 986/1024 [03:05<00:04,  8.28it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  96%|█████████▋| 988/1024 [03:05<00:03,  9.46it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  97%|█████████▋| 992/1024 [03:05<00:03, 10.55it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  97%|█████████▋| 994/1024 [03:06<00:02, 10.53it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  97%|█████████▋| 996/1024 [03:06<00:02, 10.64it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  97%|█████████▋| 998/1024 [03:06<00:02, 10.06it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  98%|█████████▊| 1002/1024 [03:06<00:02, 10.54it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  98%|█████████▊| 1006/1024 [03:07<00:01, 10.90it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  98%|█████████▊| 1008/1024 [03:07<00:01, 10.88it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  99%|█████████▉| 1012/1024 [03:07<00:01, 11.58it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  99%|█████████▉| 1014/1024 [03:07<00:00, 11.93it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
#  99%|█████████▉| 1018/1024 [03:08<00:00, 12.52it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# 100%|█████████▉| 1020/1024 [03:08<00:00, 12.91it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# 100%|██████████| 1024/1024 [03:08<00:00,  5.43it/s]
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging

# %%
display_brazil(0)

# %%
display_amazon(0)

# %%
EVAL_ONLY = True
res = tvim.train_variational_inference_model(params, eval_params, fileset, ISOSCAPE_SAVE_LOCATION, MODEL_SAVE_LOCATION, eval_only=EVAL_ONLY)
# Out:
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)

# %% [markdown]
# ## MCMC?

# %%
import pymc3 as pm

# %%
from pymc3 import pm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-2466c0b43957> in <cell line: 1>()
# ----> 1 from pymc3 import pm
#
# ImportError: cannot import name 'pm' from 'pymc3' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
help(pm)
# Out:
# Help on package pymc3:
#
# NAME
#     pymc3
#
# PACKAGE CONTENTS
#     pymc (package)
#     setup
#     setupegg
#     tests (package)
#
# FILE
#     (built-in)

# %%
import pm

# %%
help(pm.pymc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-8937eb44d669> in <cell line: 1>()
# ----> 1 help(pm.pymc)
#
# AttributeError: module 'pymc3' has no attribute 'pymc'

# %%
pm.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d3f8d1e4573c> in <cell line: 1>()
# ----> 1 pm.pymc
#
# AttributeError: module 'pymc3' has no attribute 'pymc'

# %%
dir(pm)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
help(pm.distributions.Discrete)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-8bd8555df5e1> in <cell line: 1>()
# ----> 1 help(pm.distributions.Discrete)
#
# AttributeError: module 'pymc3' has no attribute 'distributions'

# %%
# https://towardsdatascience.com/markov-chain-monte-carlo-in-python-44f7e609be98

# %%
import pymc3 as pm

with pm.Model() as model:



  step = pm.Metropolis()

  model_trace = pm.sample(100, step=step, njobs=2)

# %% [markdown]
# # Variational Inference + DNN

# %%
# Convenience links:
# Paper: https://braintex.goog/project/6509cbf324c22900a893d018
# Experiment list: https://docs.google.com/spreadsheets/d/1QUGvdUkkYCnflTytaYelMsbzGjhvR0U_HBkRdDUdeGM/edit?gid=1787854098#gid=1787854098
#

# %%
import tensorflow as tf

# %%
tf.keras.utils.set_random_seed(18731)

# %%
params = tvim.VIModelTrainingParams(
    training_id = "2025-05-23-vinn-4-rmse-mean-only-rmse-kl", #@param
    num_epochs = 2000, #@param
    num_layers = 2, #@param
    num_nodes_per_layer = 20, #@param
    training_batch_size = 3, #@param
    learning_rate = 0.0001, #@param
    mean_label = "d18O_cel_mean", #@param
    min_steps = 0, #@param
    var_label = "d18O_cel_variance", #@param
    early_stopping_patience = 100, #@param
    double_sided_kl = True, #@param
    kl_num_samples_from_pred_dist = 50, #@param
    dropout_rate = 0, #@param
    activation_func = "relu", #@param
    features_to_standardize = ['lat', 'long', 'VPD', 'RH', 'PET', 'DEM', 'PA', 'Mean Annual Temperature', 'Mean Annual Precipitation', 'Iso_Oxi_Stack_mean_TERZER', 'isoscape_fullmodel_d18O_prec_REGRESSION', 'brisoscape_mean_ISORIX', 'd13C_cel_mean', 'd13C_cel_var', 'ordinary_kriging_linear_d18O_predicted_mean', 'ordinary_kriging_linear_d18O_predicted_variance', 'd13C_foliar', 	'd15N_foliar', 'd15N_soil'], #@param
    features_to_passthrough = [], #@param
    resolution_x = 1024, #@param
    resolution_y = 1024, #@param
    tags = ["author:npr", "ViNN", "rev2"], #@param
    foo = "bar",
    n_cv_folds=None
)

eval_params = tvim.VIModelEvalParams(
    samples_per_location = 5, #@param
    precision_target = 0.95, #@param
    recall_target = None, #@param
    start_max_fraud_radius= 6, #@param
    end_max_fraud_radius = 3000, #@param
    radius_pace = 100, #@param
    trusted_buffer_radius = 5, #@param
    elements_to_eval = ['d18O_cel'], #@param
)

MODEL_SAVE_LOCATION = os.path.join(raster.GDRIVE_BASE, raster.MODEL_BASE.lstrip('/'), params.training_id + ".keras")
ISOSCAPE_SAVE_LOCATION = raster.get_raster_path(params.training_id+".tiff")

# %% [markdown]
# # Train the model

# %%
EVAL_ONLY = False #@param{type:'boolean'}

# Geotiff rendering will fail because we dont have geotiffs for 'd13C_foliar',	'd15N_foliar', nor 'd15N_soil'.
res = tvim.train_variational_inference_model(params, eval_params, fileset, ISOSCAPE_SAVE_LOCATION, MODEL_SAVE_LOCATION, eval_only=EVAL_ONLY, enable_fraud_detection_eval=False)
# Out:
# ==================
# 2025-05-23-vinn-4-rmse-mean-only-rmse-kl
# Model: "functional_35"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_35      │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_92 (Dense)    │ (None, 20)        │        400 │ input_layer_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_93 (Dense)    │ (None, 20)        │        420 │ dense_92[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ var_output (Dense)  │ (None, 1)         │         21 │ dense_93[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mean_output (Dense) │ (None, 1)         │         21 │ dense_93[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_71         │ (None, 1)         │          0 │ var_output[0][0]  │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_70         │ (None, 1)         │          0 │ mean_output[0][0] │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_71 (Add)        │ (None, 1)         │          0 │ multiply_71[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_70 (Add)        │ (None, 1)         │          0 │ multiply_70[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_182 (Cast)     │ (None, 1)         │          0 │ add_71[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_183 (Cast)     │ (None, 1)         │          0 │ add_70[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softplus_layer_35   │ (None, 1)         │          0 │ cast_182[0][0]    │
# │ (SoftplusLayer)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, 2)         │          0 │ cast_183[0][0],   │
# │ (Concatenate)       │                   │            │ softplus_layer_3… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 862 (3.37 KB)
#  Trainable params: 862 (3.37 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 10.9959 - val_loss: 4.2438
# Epoch 2/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.5289 - val_loss: 4.4319
# Epoch 3/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 11.0243 - val_loss: 4.1147
# Epoch 4/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3910 - val_loss: 3.4891
# Epoch 5/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.6244 - val_loss: 3.4205
# Epoch 6/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.6217 - val_loss: 3.4641
# Epoch 7/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8754 - val_loss: 3.2967
# Epoch 8/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6585 - val_loss: 3.3352
# Epoch 9/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.5140 - val_loss: 2.8517
# Epoch 10/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.8483 - val_loss: 2.9095
# Epoch 11/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.6574 - val_loss: 2.7985
# Epoch 12/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0519 - val_loss: 3.1029
# Epoch 13/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6578 - val_loss: 2.6207
# Epoch 14/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.6528 - val_loss: 2.6558
# Epoch 15/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1928 - val_loss: 2.4848
# Epoch 16/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.9078 - val_loss: 2.3028
# Epoch 17/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1427 - val_loss: 2.5870
# Epoch 18/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1665 - val_loss: 2.4368
# Epoch 19/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2721 - val_loss: 2.4165
# Epoch 20/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.5749 - val_loss: 2.2176
# Epoch 21/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8181 - val_loss: 2.1907
# Epoch 22/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0657 - val_loss: 2.3682
# Epoch 23/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6883 - val_loss: 2.5799
# Epoch 24/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.2224 - val_loss: 2.3053
# Epoch 25/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.8127 - val_loss: 2.5459
# Epoch 26/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2523 - val_loss: 2.3095
# Epoch 27/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4322 - val_loss: 2.3438
# Epoch 28/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.4147 - val_loss: 2.3855
# Epoch 29/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2509 - val_loss: 2.4626
# Epoch 30/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6284 - val_loss: 2.5166
# Epoch 31/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3388 - val_loss: 2.0735
# Epoch 32/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 5.8978 - val_loss: 2.4779
# Epoch 33/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2070 - val_loss: 2.1001
# Epoch 34/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7544 - val_loss: 2.2218
# Epoch 35/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9477 - val_loss: 2.6095
# Epoch 36/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8299 - val_loss: 2.1687
# Epoch 37/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2613 - val_loss: 2.2796
# Epoch 38/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9510 - val_loss: 2.6488
# Epoch 39/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2699 - val_loss: 2.5195
# Epoch 40/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5598 - val_loss: 2.1720
# Epoch 41/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5196 - val_loss: 2.4277
# Epoch 42/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.9747 - val_loss: 2.1534
# Epoch 43/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2624 - val_loss: 2.1274
# Epoch 44/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9487 - val_loss: 2.4820
# Epoch 45/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2225 - val_loss: 2.2860
# Epoch 46/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9369 - val_loss: 2.4914
# Epoch 47/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5547 - val_loss: 2.5503
# Epoch 48/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.0840 - val_loss: 2.3875
# Epoch 49/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5764 - val_loss: 2.3360
# Epoch 50/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5002 - val_loss: 2.3356
# Epoch 51/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0627 - val_loss: 2.3794
# Epoch 52/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6625 - val_loss: 2.4027
# Epoch 53/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.5232 - val_loss: 2.5601
# Epoch 54/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9264 - val_loss: 2.3221
# Epoch 55/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6958 - val_loss: 2.4047
# Epoch 56/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6515 - val_loss: 2.6711
# Epoch 57/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7414 - val_loss: 2.1524
# Epoch 58/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3866 - val_loss: 2.0951
# Epoch 59/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8231 - val_loss: 2.7428
# Epoch 60/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4762 - val_loss: 2.3743
# Epoch 61/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6581 - val_loss: 2.2119
# Epoch 62/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9565 - val_loss: 2.5248
# Epoch 63/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9682 - val_loss: 2.3720
# Epoch 64/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8425 - val_loss: 2.6255
# Epoch 65/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1604 - val_loss: 2.5843
# Epoch 66/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0421 - val_loss: 2.4799
# Epoch 67/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.8333 - val_loss: 2.6441
# Epoch 68/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3530 - val_loss: 2.8446
# Epoch 69/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7267 - val_loss: 2.5381
# Epoch 70/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1413 - val_loss: 2.6248
# Epoch 71/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5450 - val_loss: 2.4087
# Epoch 72/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1535 - val_loss: 2.6676
# Epoch 73/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.7013 - val_loss: 2.5484
# Epoch 74/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4231 - val_loss: 2.6063
# Epoch 75/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7109 - val_loss: 2.7771
# Epoch 76/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9426 - val_loss: 2.3748
# Epoch 77/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7041 - val_loss: 2.3946
# Epoch 78/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0700 - val_loss: 2.6424
# Epoch 79/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2099 - val_loss: 2.8188
# Epoch 80/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2789 - val_loss: 2.6137
# Epoch 81/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7701 - val_loss: 3.1678
# Epoch 82/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0154 - val_loss: 2.6763
# Epoch 83/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7309 - val_loss: 2.6750
# Epoch 84/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9856 - val_loss: 2.7502
# Epoch 85/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.5549 - val_loss: 2.4862
# Epoch 86/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7079 - val_loss: 2.9062
# Epoch 87/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0973 - val_loss: 2.6954
# Epoch 88/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3552 - val_loss: 2.3887
# Epoch 89/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6503 - val_loss: 2.7560
# Epoch 90/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0558 - val_loss: 2.6953
# Epoch 91/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.8015 - val_loss: 2.3975
# Epoch 92/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7912 - val_loss: 2.6776
# Epoch 93/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2617 - val_loss: 2.5323
# Epoch 94/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4742 - val_loss: 2.5445
# Epoch 95/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6563 - val_loss: 2.7212
# Epoch 96/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4340 - val_loss: 2.7351
# Epoch 97/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9222 - val_loss: 2.8944
# Epoch 98/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3851 - val_loss: 2.7000
# Epoch 99/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3911 - val_loss: 2.4993
# Epoch 100/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6506 - val_loss: 2.7854
# Epoch 101/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7949 - val_loss: 2.8070
# Epoch 102/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3389 - val_loss: 2.5424
# Epoch 103/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3098 - val_loss: 2.6261
# Epoch 104/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.7751 - val_loss: 2.9844
# Epoch 105/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9978 - val_loss: 2.2682
# Epoch 106/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3102 - val_loss: 2.6848
# Epoch 107/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4508 - val_loss: 2.4387
# Epoch 108/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2598 - val_loss: 2.4011
# Epoch 109/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.4241 - val_loss: 2.6422
# Epoch 110/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8763 - val_loss: 2.2711
# Epoch 111/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6843 - val_loss: 2.4564
# Epoch 112/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6487 - val_loss: 2.6413
# Epoch 113/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2530 - val_loss: 2.4781
# Epoch 114/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.7545 - val_loss: 2.5939
# Epoch 115/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1558 - val_loss: 2.5688
# Epoch 116/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.2449 - val_loss: 2.9554
# Epoch 117/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3961 - val_loss: 2.5769
# Epoch 118/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.3373 - val_loss: 2.7717
# Epoch 119/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8985 - val_loss: 2.6906
# Epoch 120/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.8575 - val_loss: 2.5432
# Epoch 121/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.8811 - val_loss: 2.8818
# Epoch 122/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2152 - val_loss: 2.4497
# Epoch 123/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9242 - val_loss: 2.8132
# Epoch 124/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7821 - val_loss: 2.6251
# Epoch 125/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4164 - val_loss: 2.3483
# Epoch 126/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9888 - val_loss: 2.4180
# Epoch 127/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.1133 - val_loss: 2.7726
# Epoch 128/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.3994 - val_loss: 2.6873
# Epoch 129/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5243 - val_loss: 2.4342
# Epoch 130/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6402 - val_loss: 2.6560
# Epoch 131/2000
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0244 - val_loss: 2.8620
# Epoch 131: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Val loss: 2.073516368865967
# Train loss: 5.400617599487305
# Test loss: 7.504580974578857
# dO18 RMSE: {'mean_rmse': np.float64(1.2424455892440402), 'var_rmse': np.float64(0.5097143452027529)}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-f6cf0b288495> in <cell line: 0>()
#       2
#       3 # Geotiff rendering will fail because we dont have geotiffs for 'd13C_foliar',  'd15N_foliar', nor 'd15N_soil'.
# ----> 4 res = tvim.train_variational_inference_model(params, eval_params, fileset, ISOSCAPE_SAVE_LOCATION, MODEL_SAVE_LOCATION, eval_only=EVAL_ONLY, enable_fraud_detection_eval=False)
#
# /content/gdrive/MyDrive/rmse/ddf_common/train_variational_inference_model.py in train_variational_inference_model(training_params, eval_params, files, isoscape_save_location, model_save_location, eval_only, enable_fraud_detection_eval)
#     212       packaged_model = model.TFModel(model_save_location, f"{model_save_location.strip('.keras')}.pkl")
#     213
# --> 214       generate_isoscape.generate_isoscapes_from_variational_model(
#     215           packaged_model,
#     216           training_params.resolution_x,
#
# /content/gdrive/MyDrive/rmse/ddf_common/generate_isoscape.py in generate_isoscapes_from_variational_model(vi_model, res_x, res_y, output_geotiff_save_location, amazon_only)
#     205     feature_transformer = vi_model.transformer
#     206
# --> 207   preds = get_predictions_at_each_pixel(
#     208     vi_model, input_geotiffs, output_resolution,
#     209     geometry_mask=arbitrary_geotiff,
#
# /content/gdrive/MyDrive/rmse/ddf_common/generate_isoscape.py in get_predictions_at_each_pixel(model, geotiffs, bounds, geometry_mask, feature_transformer)
#      64                          Input must be transformed prior to predictions."""
#      65
# ---> 66   check_same_order(list(geotiffs.keys()), model.training_column_names())
#      67
#      68   # Initialize a blank plane representing means and variance.
#
# /content/gdrive/MyDrive/rmse/ddf_common/generate_isoscape.py in check_same_order(expected, actual)
#      42   actual.remove("long")
#      43   if (expected != actual):
# ---> 44     raise ValueError("Geotiff inputs don't match the inputs expected by the model")
#      45
#      46 def get_predictions_at_each_pixel(
#
# ValueError: Geotiff inputs don't match the inputs expected by the model

# %% [markdown]
# # Optional Rendering

# %%
from matplotlib import rc
rc('animation', html='jshtml')

means_isoscape = raster.load_raster(ISOSCAPE_SAVE_LOCATION, use_only_band_index=0)
raster.animate(means_isoscape,  1, 1)
# Out:
# Driver: GTiff/GeoTIFF
# Size is 1024 x 1024 x 2
# Projection is GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]
# Origin = (-74.0000000000241, 5.29166666665704)
# Pixel Size = (0.03828938802082461, -0.03812662760417103)

# %%
vars_isoscape = raster.load_raster(ISOSCAPE_SAVE_LOCATION, use_only_band_index=1)
raster.animate(vars_isoscape,  1, 1)
